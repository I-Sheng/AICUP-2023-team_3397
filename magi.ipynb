# %% [markdown]
# # magi Notebook
#
# ## ML Dependencies
# - [sentence-transformer](https://www.sbert.net/examples/applications/semantic-search/README.html)
# - [OpenAI GPT-3.5 Turbo](https://platform.openai.com/docs/models/gpt-3-5)
#
# ## Dataset
# The official dataset and cached data is at this [Google Drive folder](https://drive.google.com/drive/u/1/folders/1ZfmEKn_nU3fkwxG2Xfg7e_-00o67OR8t)
#
# ## Terms
# 1. answers: train data
# 2. wikis: wiki data
# 3. queries: test data
#
# ## Process
# 1. Embed answers and wikis
# 2. Embed queries
# 3. Search top answers for queries
# 4. Search top wikis for queries
# 5. Rank all search results of `3.` and `4.` and generate labels for queries with OpenAI's GPT
# 6. Summarize generated labels
#
# ## Notes
# 1. All heavy tasks are preprocessed and their outputs are cached
# 2. For user to replay, the minimum hardware requirements is a 8GB RAM and CPU. You can run on Google Colab for FREE.
# 3. For developer to train, it is recommended to subscript to Google Colab Pro, use GPU A100, and optimize hyper parameters before running.

# %%
# !gdown --folder 1ZfmEKn_nU3fkwxG2Xfg7e_-00o67OR8t && \
mv ./NLP2023/data . && \
rm -r NLP2023
# Out:
# Retrieving folder list
# Retrieving folder 1Fxac18gg5ig5oB7Dny27HORZNILzO828 data
# Retrieving folder 1GyE2CDAVTwB28wN1FNGyyHjN6iYiJBdI caches
# Processing file 11pbOIDVzdLH9g7Kh9bUEWnx_x-0bO9es answer_candicates.json
# Processing file 1fcBCorOh5xonCI1o8STHYxIHSwjPrPQr answer_embeddings.pt
# Processing file 1gaaoVwjfpk7KitmhxjtvT2P5TYgfnQ_4 answers.json
# Processing file 1_imy7bKAMORAToyIZcA4mArPVd-ehE6_ wiki_candicates.json
# Processing file 1xbSjr9VK_HWwV44aJDuCBaTuSI1MMwyT wiki_embeddings.pt
# Processing file 1AuMvHa8Cznwa0H3iuV87ecK4DDcg8bDi wikis.json
# Retrieving folder 15XXuLVNCTdzgJXTqsJoFxCf9WSohkCwq test
# Processing file 1vndQLFgWIy0so4eHUNkdNPM3HyxRoJxD private_test_data.jsonl
# Processing file 1-NdCRpB6DfKGXKOj5KISdHHbxTh_Xa2n public_test_data.jsonl
# Retrieving folder 19nTqjOYhqW0nay-GLpwDkJC3oogg4psY train
# Processing file 1rUxHXSblBHHXtxrFUCxia40JeomouQCp public_train_data_0.jsonl
# Processing file 1XbRBh8dZinI6BPEQ9cP7IgAH-KW6K-HD public_train_data_1.jsonl
# Retrieving folder 1opwtjerhopHBgDx4rMnc4HsTkCfed0BI wiki-pages
# Processing file 1oJfjuuNCmY1QVKZTktz11mk_76kDnZiv wiki-001.jsonl
# Processing file 1YuqhBDBWXJ9l-HUfcWpf3koEZOH_w_iD wiki-002.jsonl
# Processing file 1n8bZ5RV3cIy6UKSon1wabFQ1rbHqFqPs wiki-003.jsonl
# Processing file 1WbX7j3Xj-bJ9ZwAgltnGVL2bUh7lmvrk wiki-004.jsonl
# Processing file 1brvDez1Ym4BDQEz9HEc8nf9CEKNpfEXR wiki-005.jsonl
# Processing file 1lkgxthFOYzsQjMvGLHUz_8Xuqc8WQBbn wiki-006.jsonl
# Processing file 16TdxsFLuowbJkwDe5OiyDF4bz7_BjFX4 wiki-007.jsonl
# Processing file 1KD1jinLLOf4aKsoLojo08yxG6k5vFdWQ wiki-008.jsonl
# Processing file 1BaglSSorJWij_3ungPNiZhUhzfIadooC wiki-009.jsonl
# Processing file 1_Ec5r0JznfruJFDc1UFwptoIQZDD6FPU wiki-010.jsonl
# Processing file 1MMpekJ8YPToRAY-qv9N5ZIyFBPA_Szbj wiki-011.jsonl
# Processing file 1JknHxD00v_vtGKoAU1nGBznEWSqKuCgy wiki-012.jsonl
# Processing file 13eaWfVu5lfeEoVUj2O-3eeR-_ZoGiXuU wiki-013.jsonl
# Processing file 10PNR_p6o0ovstU14qNd_fbK9N8yw9uRZ wiki-014.jsonl
# Processing file 1sgtBwSqeYXluvP9GZ1PalwlgbwXKm_If wiki-015.jsonl
# Processing file 1hvrOnl7RSv_T_JM4TKpltdQj55TqF1oZ wiki-016.jsonl
# Processing file 17zfF6tYGG9O80p5EzjPi9TZS3ZPWrdzA wiki-017.jsonl
# Processing file 1F51QGo66lWf5gs64VYX5_ladHfAmIiIA wiki-018.jsonl
# Processing file 10__ESFjExtndPVPVM8d91D8LYpQTMWJs wiki-019.jsonl
# Processing file 1r_cvqVmfbtLBzg6qEdkvYAq6hObss0ur wiki-020.jsonl
# Processing file 1ebCC_THWQ3F9ltOvRA5RGCw8te8iYJnP wiki-021.jsonl
# Processing file 1yVEX80Ye9M4dOrxJ0P4im_mjN9ADHx66 wiki-022.jsonl
# Processing file 1Q4MemabXqcnm6nFupB1YBvsA9rOBXbzk wiki-023.jsonl
# Processing file 1uh6rTK2nqK8yjijwjzo_7PsndAnixXSb wiki-024.jsonl
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=11pbOIDVzdLH9g7Kh9bUEWnx_x-0bO9es
# To: /content/NLP2023/data/caches/answer_candicates.json
# 100% 7.03M/7.03M [00:00<00:00, 130MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fcBCorOh5xonCI1o8STHYxIHSwjPrPQr
# To: /content/NLP2023/data/caches/answer_embeddings.pt
# 100% 17.8M/17.8M [00:00<00:00, 158MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1gaaoVwjfpk7KitmhxjtvT2P5TYgfnQ_4
# To: /content/NLP2023/data/caches/answers.json
# 100% 1.63M/1.63M [00:00<00:00, 197MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_imy7bKAMORAToyIZcA4mArPVd-ehE6_
# To: /content/NLP2023/data/caches/wiki_candicates.json
# 100% 10.8M/10.8M [00:00<00:00, 42.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1xbSjr9VK_HWwV44aJDuCBaTuSI1MMwyT
# To: /content/NLP2023/data/caches/wiki_embeddings.pt
# 100% 1.82G/1.82G [00:21<00:00, 82.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1AuMvHa8Cznwa0H3iuV87ecK4DDcg8bDi
# To: /content/NLP2023/data/caches/wikis.json
# 100% 510M/510M [00:05<00:00, 87.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vndQLFgWIy0so4eHUNkdNPM3HyxRoJxD
# To: /content/NLP2023/data/test/private_test_data.jsonl
# 100% 1.00M/1.00M [00:00<00:00, 112MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-NdCRpB6DfKGXKOj5KISdHHbxTh_Xa2n
# To: /content/NLP2023/data/test/public_test_data.jsonl
# 100% 116k/116k [00:00<00:00, 73.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rUxHXSblBHHXtxrFUCxia40JeomouQCp
# To: /content/NLP2023/data/train/public_train_data_0.jsonl
# 100% 795k/795k [00:00<00:00, 143MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1XbRBh8dZinI6BPEQ9cP7IgAH-KW6K-HD
# To: /content/NLP2023/data/train/public_train_data_1.jsonl
# 100% 1.65M/1.65M [00:00<00:00, 191MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oJfjuuNCmY1QVKZTktz11mk_76kDnZiv
# To: /content/NLP2023/data/train/wiki-pages/wiki-001.jsonl
# 100% 72.2M/72.2M [00:00<00:00, 228MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YuqhBDBWXJ9l-HUfcWpf3koEZOH_w_iD
# To: /content/NLP2023/data/train/wiki-pages/wiki-002.jsonl
# 100% 57.5M/57.5M [00:00<00:00, 152MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1n8bZ5RV3cIy6UKSon1wabFQ1rbHqFqPs
# To: /content/NLP2023/data/train/wiki-pages/wiki-003.jsonl
# 100% 57.6M/57.6M [00:01<00:00, 38.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WbX7j3Xj-bJ9ZwAgltnGVL2bUh7lmvrk
# To: /content/NLP2023/data/train/wiki-pages/wiki-004.jsonl
# 100% 55.4M/55.4M [00:00<00:00, 205MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1brvDez1Ym4BDQEz9HEc8nf9CEKNpfEXR
# To: /content/NLP2023/data/train/wiki-pages/wiki-005.jsonl
# 100% 45.8M/45.8M [00:00<00:00, 132MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1lkgxthFOYzsQjMvGLHUz_8Xuqc8WQBbn
# To: /content/NLP2023/data/train/wiki-pages/wiki-006.jsonl
# 100% 47.2M/47.2M [00:00<00:00, 55.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=16TdxsFLuowbJkwDe5OiyDF4bz7_BjFX4
# To: /content/NLP2023/data/train/wiki-pages/wiki-007.jsonl
# 100% 50.2M/50.2M [00:00<00:00, 157MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KD1jinLLOf4aKsoLojo08yxG6k5vFdWQ
# To: /content/NLP2023/data/train/wiki-pages/wiki-008.jsonl
# 100% 39.1M/39.1M [00:00<00:00, 123MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BaglSSorJWij_3ungPNiZhUhzfIadooC
# To: /content/NLP2023/data/train/wiki-pages/wiki-009.jsonl
# 100% 21.8M/21.8M [00:00<00:00, 161MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_Ec5r0JznfruJFDc1UFwptoIQZDD6FPU
# To: /content/NLP2023/data/train/wiki-pages/wiki-010.jsonl
# 100% 34.2M/34.2M [00:00<00:00, 49.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MMpekJ8YPToRAY-qv9N5ZIyFBPA_Szbj
# To: /content/NLP2023/data/train/wiki-pages/wiki-011.jsonl
# 100% 27.4M/27.4M [00:00<00:00, 180MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1JknHxD00v_vtGKoAU1nGBznEWSqKuCgy
# To: /content/NLP2023/data/train/wiki-pages/wiki-012.jsonl
# 100% 30.0M/30.0M [00:00<00:00, 146MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=13eaWfVu5lfeEoVUj2O-3eeR-_ZoGiXuU
# To: /content/NLP2023/data/train/wiki-pages/wiki-013.jsonl
# 100% 23.3M/23.3M [00:00<00:00, 70.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10PNR_p6o0ovstU14qNd_fbK9N8yw9uRZ
# To: /content/NLP2023/data/train/wiki-pages/wiki-014.jsonl
# 100% 39.7M/39.7M [00:00<00:00, 74.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sgtBwSqeYXluvP9GZ1PalwlgbwXKm_If
# To: /content/NLP2023/data/train/wiki-pages/wiki-015.jsonl
# 100% 41.8M/41.8M [00:00<00:00, 122MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hvrOnl7RSv_T_JM4TKpltdQj55TqF1oZ
# To: /content/NLP2023/data/train/wiki-pages/wiki-016.jsonl
# 100% 42.5M/42.5M [00:00<00:00, 163MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17zfF6tYGG9O80p5EzjPi9TZS3ZPWrdzA
# To: /content/NLP2023/data/train/wiki-pages/wiki-017.jsonl
# 100% 41.1M/41.1M [00:01<00:00, 35.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1F51QGo66lWf5gs64VYX5_ladHfAmIiIA
# To: /content/NLP2023/data/train/wiki-pages/wiki-018.jsonl
# 100% 40.6M/40.6M [00:00<00:00, 55.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10__ESFjExtndPVPVM8d91D8LYpQTMWJs
# To: /content/NLP2023/data/train/wiki-pages/wiki-019.jsonl
# 100% 40.9M/40.9M [00:00<00:00, 62.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1r_cvqVmfbtLBzg6qEdkvYAq6hObss0ur
# To: /content/NLP2023/data/train/wiki-pages/wiki-020.jsonl
# 100% 41.5M/41.5M [00:00<00:00, 128MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ebCC_THWQ3F9ltOvRA5RGCw8te8iYJnP
# To: /content/NLP2023/data/train/wiki-pages/wiki-021.jsonl
# 100% 40.4M/40.4M [00:00<00:00, 194MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1yVEX80Ye9M4dOrxJ0P4im_mjN9ADHx66
# To: /content/NLP2023/data/train/wiki-pages/wiki-022.jsonl
# 100% 39.4M/39.4M [00:00<00:00, 146MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Q4MemabXqcnm6nFupB1YBvsA9rOBXbzk
# To: /content/NLP2023/data/train/wiki-pages/wiki-023.jsonl
# 100% 38.2M/38.2M [00:00<00:00, 123MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1uh6rTK2nqK8yjijwjzo_7PsndAnixXSb
# To: /content/NLP2023/data/train/wiki-pages/wiki-024.jsonl
# 100% 34.1M/34.1M [00:00<00:00, 87.7MB/s]
# Download completed

# %%
# install dependencies

# !pip install sentence-transformers \
msgspec \
tqdm \
numpy \
torch \
openai \
python-dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
#   Preparing metadata (setup.py) ... done
# Collecting msgspec
#   Using cached msgspec-0.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (183 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Collecting openai
#   Using cached openai-0.27.7-py3-none-any.whl (71 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Collecting aiohttp (from openai)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 6.2 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->openai)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->openai)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 13.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->openai)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=6cbf8bfe13bb1ff02a5a5b5cb6844a1af49624eb32ea2706a86e8132751bbf6a
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, python-dotenv, multidict, msgspec, frozenlist, async-timeout, yarl, huggingface-hub, aiosignal, transformers, aiohttp, openai, sentence-transformers
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 huggingface-hub-0.14.1 msgspec-0.15.1 multidict-6.0.4 openai-0.27.7 python-dotenv-1.0.0 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.29.2 yarl-1.9.2

# %%
# import dependencies

from sentence_transformers import SentenceTransformer, util
from msgspec.json import decode, encode
from tqdm import tqdm
import numpy
from numpy import random
import torch
from torch import Tensor
from dotenv import load_dotenv
import openai

import re
import json
from os import getenv
from pathlib import Path
from itertools import chain
from time import sleep
from datetime import date, timedelta
from pprint import pprint # [DEV]
from typing_extensions import TypedDict
from typing import Any, Union, Literal

# %%
# Public hyper parameters

# TRAIN_SPEED
# type:
#   name: int
#   range: [32, 1024]
# Side effects if increased include higher memory usage
TRAIN_SPEED: int = 64

# RNG_SEED
# type:
#   name: int
# Universal seed for all random number generators used
RNG_SEED: int = 94248763

# Private hyper parameters

_BATCH_SIZE = 1 << (
  int(min(max(TRAIN_SPEED, 32), 2048)) >> 1
).bit_length()

_RNG_1 = random.Generator(
  random.SFC64(RNG_SEED)
)

# %%
# Pre-trained model reference: https://www.sbert.net/docs/pretrained_models.html

ml_embedder = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# Downloading (…)0fe39/.gitattributes:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)83e900fe39/README.md:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading (…)e900fe39/config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading unigram.json:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading (…)900fe39/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
# Typings

Label = Literal['supports', 'refutes', 'NOT ENOUGH INFO']

Evidence = tuple[str, int]

Embeddings = list[Tensor]

Answers = TypedDict('Answers', {
  'claim': list[str],
  'label': list[Label],
  'evidences': list[list[Evidence]],
})

Answer = TypedDict('Answer', {
  'claim': str,
  'label': Label,
  'evidences': list[Evidence],
})

Wikis = dict[str, list[str]]

Queries = dict[int, str]

Candicates = list[tuple[float, Answer]]

Submission = TypedDict('Submission', {
  'id': int,
  'predicted_label': Label,
  'predicted_evidence': list[Evidence] | None,
})

# %%
# make caches directory

cache_dir = Path('./data/caches/')
if not cache_dir.exists():
  cache_dir.mkdir()

# %%
# load answers from ./data/train/public_train_data_(0|1).json
# or cached answers
# at ./data/caches/answers.json
# and ./data/caches/answer_embeddings.pt

answers: Answers = {
  'claim': [],
  'label': [],
  'evidences': [],
}
answer_embeddings: Embeddings = []

# tool functions

def to_evidences(evidence: list) -> list[Evidence]:
  _f = lambda *n: (
    e for a in n
      for e in (_f(*a) if isinstance(a, (list, tuple)) else (a,))
  )
  flatten = list(_f(evidence))
  ids = flatten[2::4]
  indices = flatten[3::4]
  return list(zip(ids, indices)) if ids[0] else []

cache_file = cache_dir.joinpath('answers.json')
cache_file_2 = cache_dir.joinpath('answer_embeddings.pt')

if not cache_file.exists() or not cache_file_2.exists():
  answer_embeddings_source: list[str] = []

  for line in tqdm(list(chain(*[
    open(f'./data/train/public_train_data_{i}.jsonl')
    for i in range(2)
  ]))):
    answer = decode(line)
    answers['claim'].append(answer['claim'])
    answers['label'].append(answer['label'])
    answers['evidences'].append(to_evidences(answer['evidence']))
    answer_embeddings_source.append(answer['claim'])

  answer_embeddings = ml_embedder.encode(
    answer_embeddings_source,
    convert_to_tensor=True,
    show_progress_bar=True,
    batch_size=_BATCH_SIZE,
  )

  cache_file.write_bytes(encode(answers))
  torch.save(answer_embeddings, open(cache_file_2, 'wb'))
else:
  answers = decode(cache_file.read_bytes())
  answer_embeddings = torch.load(
    open(cache_file_2, 'rb'),
    lambda s, l: s.cuda(0) if torch.cuda.is_available() else s,
  )
  print(len(answer_embeddings))

cache_file = None
cache_file_2 = None
# Out:
# 11620

# %%
# load wikis from ./data/train/wiki-pages/wiki-{:03d}.jsonl
# or cached wikis
# at ./data/caches/wikis.json
# and ./data/caches/wiki_embeddings.pt

wikis: Wikis = {}
wiki_embeddings: Embeddings = []

cache_file = cache_dir.joinpath('wikis.json')
cache_file_2 = cache_dir.joinpath('wiki_embeddings.pt')

if not cache_file.exists() or not cache_file_2.exists():
  wiki_embeddings_source: list[str] = []
  for line in tqdm(list(chain(*[
    open(f'./data/train/wiki-pages/wiki-{i:03d}.jsonl')
    for i in range(1, 25)
  ]))):
    wiki = decode(line)

    lines_no_prefix = re.sub(
      r'[0-9]+\t', '',
      wiki['lines'],
    )
    lines = lines_no_prefix.replace('\t', ' ').split('\n')
    wikis[wiki['id']] = lines

    wiki_embeddings_source.append(
      f"{wiki['id']}的簡述：{wiki['text'][:100]}"
    )

  wiki_embeddings = ml_embedder.encode(
    wiki_embeddings_source,
    convert_to_tensor=True,
    show_progress_bar=True,
    batch_size=_BATCH_SIZE,
  )

  cache_file.write_bytes(encode(wikis))
  torch.save(wiki_embeddings, open(cache_file_2, 'wb'))
else:
  wikis = decode(cache_file.read_bytes())
  wiki_embeddings = torch.load(
    open(cache_file_2, 'rb'),
    lambda s, l: s.cuda(0) if torch.cuda.is_available() else s,
  )
  print(len(wiki_embeddings))

cache_file = None
cache_file_2 = None
# Out:
# 1187751

# %%
# load queries
# from ./data/public_test.jsonl
# and ./data/private_test.jsonl

queries: Queries = {}

for line in tqdm(list(chain(
  open('./data/test/public_test_data.jsonl'),
  open('./data/test/private_test_data.jsonl'),
))):
  query = decode(line)
  queries[query['id']] = query['claim']
# Out:
# 100%|██████████| 9038/9038 [00:00<00:00, 136888.99it/s]

# %%
# [LSS], [FS], [L], [S], [R]
# 1. Large Semantic Search [LSS]
# 2. Filter by Score [FS]
# 3. Label and Summarize [LS]
# 4. Respond [R]

# %%
# 1. Large Semantic Search [LSS]

# choose candicates for each query
# or load cached candicates
# from ./data/caches/answer_candicates.json
# and ./data/caches/wiki_candicates.json
#
# type of candicates: dict[query_id, Candicates]

query_embeddings = None

def _object_hook(x):
  try:
    return {int(k): v for k, v in x.items()}
  except:
    return x

# choose from answers

answer_candicates: dict[int, Candicates] = {}

cache_file = cache_dir.joinpath('answer_candicates.json')

if not cache_file.exists():
  if not query_embeddings:
    query_embeddings = ml_embedder.encode(
      list(queries.values()),
      convert_to_tensor=True,
      show_progress_bar=True,
      batch_size=_BATCH_SIZE,
    )

  answer_top_results = util.semantic_search(
    query_embeddings,
    answer_embeddings,
    top_k=4,
  )

  answer_candicates = {
    query_id: [
      (
        _['score'],
        {
          'claim': answers['claim'][_['corpus_id']],
          'label': answers['label'][_['corpus_id']],
          'evidences': answers['evidences'][_['corpus_id']],
        }
      )
      for _ in top_results
    ]
    for query_id, top_results in zip(
      queries.keys(),
      answer_top_results
    )
  }

  cache_file.write_bytes(encode(answer_candicates))
else:
  answer_candicates = json.loads(
    cache_file.read_bytes(),
    object_hook=_object_hook,
  )

answer_embeddings = None

# choose from wiki
# wave-1: choose 12 pages from 1.2M wiki pages
# wave-2: choose 4 lines from 12 pages' lines

wiki_candicates: dict[int, Candicates] = {}

cache_file = cache_dir.joinpath('wiki_candicates.json')

if not cache_file.exists():
  if not query_embeddings:
    query_embeddings = ml_embedder.encode(
      list(queries.values()),
      convert_to_tensor=True,
      show_progress_bar=True,
      batch_size=_BATCH_SIZE,
    )

  wiki_top_results = util.semantic_search(
    query_embeddings,
    wiki_embeddings,
    top_k=12,
  )

  wiki_ids: list[str] = list(wikis.keys())

  for query_id, query_embedding, top_results in tqdm(list(zip(
    queries.keys(),
    query_embeddings,
    wiki_top_results,
  ))):
    wiki_claims: list[str] = []
    wiki_evidences: list[Evidence] = []

    for _ in top_results:
      for index, line in enumerate(wikis[wiki_ids[_['corpus_id']]]):
        wiki_claims.append(''.join(
          wikis[wiki_ids[_['corpus_id']]][index:index+2]
        ))
        wiki_evidences.append((wiki_ids[_['corpus_id']], index))

    wiki_claim_embeddings = ml_embedder.encode(
      wiki_claims,
      convert_to_tensor=True,
    )
    top_results = util.semantic_search(
      query_embedding,
      wiki_claim_embeddings,
      top_k=4,
    )[0]
    wiki_candicates[query_id] = [
      (
        _['score'],
        {
          'claim': wiki_claims[_['corpus_id']],
          'label': 'supports',
          'evidences': [wiki_evidences[_['corpus_id']]],
        }
      )
      for _ in top_results
    ]

  cache_file.write_bytes(encode(wiki_candicates))
else:
  # The type of query's id is always int
  wiki_candicates = json.loads(
    cache_file.read_bytes(),
    object_hook=_object_hook,
  )

cache_file = None
wiki_embeddings = None
query_embeddings = None

# %%
# 2. Filter by Score [FS]

candicates: dict[int, Candicates] = {}

for query_id in queries.keys():
  sorted_candicates: Candicates = sorted(
    [
      (score, {'type': 'answer', **answer})
      for score, answer in answer_candicates[query_id]
    ] +
    [
      (score, {'type': 'wiki', **answer})
      for score, answer in wiki_candicates[query_id]
    ],
    reverse=True,
    key=lambda t: t[0],
  )
  pivot = 3
  for score, cand in sorted_candicates[pivot:]:
    if (
      (cand['type'] == 'answer' and score >= 0.85) or
      (cand['type'] == 'wiki' and score >= 0.55)
    ):
      pivot += 1
    else:
      break
  candicates[query_id] = sorted_candicates[:pivot]

# %%
for qid, cand in list(candicates.items())[:20:]:
  pprint([(int(score * 100) / 100, ans['claim']) for score, ans in cand])
# Out:
# [(0.97, '光學顯微鏡是以物理原理來將不可見或難見的微小物放大至肉眼可見的儀器。'),
#  (0.94, '光學顯微鏡是以凸透鏡成像來將不可見或難見的微小物放大至肉眼可見的儀器。'),
#  (0.93, '光學顯微鏡是以光學原理來將不可見或難見的微小物放大至肉眼可見的武器。'),
#  (0.85,
#   '顯微鏡泛指將微小不可見或難見物品之影像放大 ， 而能被肉眼或其他成像儀器觀察之工具 。 日常用語中之顯微鏡多指光學顯微鏡 ， 放大倍率和清析度 （ '
#   '聚焦 ） 爲顯微鏡重要因素 。 '),
#  (0.83,
#   '透射顯微鏡的物體是透明的或非常薄 ， 光從可透過它進入顯微鏡 。 顯微鏡 顯微鏡 物體 物體 光 光這種顯微鏡常被用來觀察生物組織 。 顯微鏡 '
#   '顯微鏡'),
#  (0.81,
#   '光學顯微鏡依樣品的不同可分爲反射式和透射式 。 顯微鏡 顯微鏡 光學 光學反射顯微鏡的物體一般是不透明的 ， 光從上面照在物體上 ， '
#   '被物體反射的光進入顯微鏡 。 顯微鏡 顯微鏡 物體 物體 光 光'),
#  (0.78,
#   '光學顯微鏡 （ Optical microscope 、 Light microscope ） 是一種利用光學透鏡產生影像放大效應的顯微鏡 。 顯微鏡 '
#   '顯微鏡 光學 光學 透鏡 透鏡 影像 影像')]
# [(0.96, '產絲的蠶或產蜜的蜜蜂爲提供利益的昆蟲。'),
#  (0.95, '有些昆蟲可以直接提供經濟上的利益，例如蠶產絲或是蜜蜂產蜂蜜。'),
#  (0.95, '產絲綢原料的家蠶或採集植物花蜜的蜜蜂爲提供直接經濟利益的昆蟲。')]
# [(0.73, '波蘭西部的綠山城縣平均每平方公里的土地有數十人。'),
#  (0.73, '綠山城縣位於波蘭西部，平均每1萬平方公尺的土地有75人。'),
#  (0.73, '波蘭西部的綠山城縣平均每平方公里的土地有75人。')]
# [(0.97, 'Vivien Leigh主演魂斷藍橋的女主角。'),
#  (0.89, '魂斷藍橋的女主角由Vivien Leigh主演。'),
#  (0.86, '魂斷藍橋的角色由Vivien Leigh主演。')]
# [(0.97, '侯孝賢改編自唐代傳聞的電影獲得金馬獎最佳劇情片獎。'),
#  (0.96, '侯孝賢改編自唐代傳奇的電影獲得金馬獎最佳劇情片獎。'),
#  (0.94, '侯孝賢執導的唐代傳奇改編的電影獲得金馬獎最佳劇情片獎。'),
#  (0.86, '侯孝賢改編自唐代傳奇的武俠電影獲得金馬獎最佳劇情片獎。'),
#  (0.78,
#   '李行  ， 本名李子達 ， 江蘇武進人 ， 生於上海 ， 電影導演 。 電影導演 電影導演縱橫影界逾70年 ， 在臺語片 、 健康寫實 、 '
#   '瓊瑤電影都有代表作 ， 3次榮獲金馬獎最佳導演獎 ， 有7部作品榮獲金馬獎最佳劇情片獎 （ 分別是 《 養鴨人家 》 、 《 路 》 、 《 秋決 》 '
#   '、 《 吾土吾民 》 、 《 汪洋中的一條船 》 、 《 小城故事 》 、 《 早安臺北 》 ） ， 對臺灣電影影響深遠 ， 被稱爲 「 臺灣電影教父 '
#   '」 。 汪洋中的一條船 汪洋中的一條船 (電影) 小城故事 小城故事 養鴨人家 養鴨人家 秋決 秋決 (電影) 路 路_(電影) 吾土吾民 吾土吾民 '
#   '早安臺北 早安臺北'),
#  (0.77, '本片榮獲南特影展最佳劇情片獎 、 亞太影展最佳導演獎 。 '),
#  (0.76, '鄧育昆  ， 臺灣編劇 ， 曾獲得金馬獎最佳編劇 。 '),
#  (0.76,
#   '是臺灣演員李康生執導的第一部電影作品 ， 由蔡明亮監製 。 本片獲得鹿特丹影展最大獎 「 老虎獎 」 和釜山影展最大獎 「 新潮流獎 」 ， '
#   '並獲得金馬獎包含最佳劇情片在內的四項提名 。 ')]
# [(0.87, '國務院前副總理的兒子薄熙來在2012年9月被開除黨籍 。'),
#  (0.85, '2012年9月被開除黨籍的薄熙來是國務院前副總理的兒子。'),
#  (0.76, '國務院前副總理的兒子薄熙來已被開除黨籍 。')]
# [(0.85, '水星凌日是一種天文現象 。 天文現象 天文現象 水星 水星'),
#  (0.82, '水星凌日發生在五月初或十一月初 ， 平均每百年出現十三次水星凌日的現象 。 水星 水星'),
#  (0.8,
#   '水星凌日是一種天文現象 。 天文現象 天文現象 水星 水星當水星運行至地球和太陽之間 ， 如果三者能夠連成直線 ， 便會產生水星凌日現象 。 水星 '
#   '水星 地球 地球 太陽 太陽'),
#  (0.8,
#   '水星凌日是當水星運行到太陽和金星之間時發生的一種罕見的天文現象 。 當水星凌日出現 ， 從金星上可以看到水星像一個黑色圓盤從太陽表面劃過 。 ')]
# [(1.0, '馬克思在自己的作品中論述了馬克思主義政治經濟學的基本概念。'),
#  (1.0, '馬克思在自己的作品中論述了馬克思主義政治經濟學的基本概念。'),
#  (1.0, '馬克思在自己的作品中論述了馬克思主義政治經濟學的基本概念。'),
#  (1.0, '馬克思在自己的作品中論述了馬克思主義政治經濟學的基本概念。'),
#  (0.87,
#   '馬克思主義政治經濟學 ， 也稱馬克思主義經濟學 ， 馬克思在其著作 《 資本論 》 中闡述了該學說的基本觀點 。 馬克思 馬克思 資本論 資本論 '
#   '經濟學 經濟學馬克思研究了資本主義經濟學的理論和英國曆年的經濟統計資料 ， 對資本主義經濟學理論進行了分析和批判 。 馬克思 馬克思 資本主義 '
#   '資本主義 經濟學 經濟學'),
#  (0.81, 'Category : 馬克思主義經濟學 馬克思 馬克思'),
#  (0.81, 'Category : 馬克思主義經濟學 馬克思 馬克思'),
#  (0.8,
#   '社會主義政治經濟學的理論主要依據馬克思的 《 資本論 》 ， 馬克思在資本論中分析了早期資本主義政治經濟學的不足 ， '
#   '指出自由竟爭經濟必然要導致週期性經濟危機 ， 要解決這個問題只有走計劃經濟的路 ， 但計劃經濟如何搞 ， 馬克思沒有其實踐 ， 也無法具體指導 。 '
#   '馬克思 馬克思 資本論 資本論 資本主義政治經濟學 資本主義政治經濟學 經濟危機 經濟危機')]
# [(0.96, '一貫道相信最高神祇無生老母派遣轉世成路中一的彌勒佛拯救凡間。'),
#  (0.92, '最高神祇無生老母派遣彌勒佛轉生爲路中一來拯救凡間，是一貫道所相信的。'),
#  (0.8, '一貫道信奉無生老母是創造天地者，而無生老母是許多宗教的最高神祇。')]
# [(0.87, '回族世居於長江流域西北地帶，受中亞與西亞中伊斯蘭教傳播的影響 ， 許多回族成爲穆斯林。'),
#  (0.83, '回族世居於黃河流域西北地帶，受中亞與西亞中伊斯蘭教傳播的影響 ， 許多回族成爲穆斯林。'),
#  (0.82, '回族世居於黃河流域西北地帶，受亞洲伊斯蘭教傳播的影響 ， 許多回族成爲穆斯林。')]
# [(0.98, '天衛四的表面呈現暗紅色，其主要地形是小行星和彗星撞擊後所形成的，並存在許多撞擊坑。'),
#  (0.97, '天衛四的表面呈現暗紅色，其主要地形是流星和彗星撞擊後所形成的，並存在許多撞擊坑。'),
#  (0.96, '天衛四的表面呈現暗紅色，其主要地形是小行星和彗星撞擊後所形成的，並使原坑洞撞平。'),
#  (0.95, '天衛四的表面呈現暗紅色，其主要峽谷地形是小行星和彗星撞擊後所形成的，並存在許多撞擊坑。'),
#  (0.79, '該撞擊坑是小行星撞擊而形成 。 雷達探測發現該撞擊坑有一個崎嶇的中央山和一個在雷達影像中黑暗的平坦底部 ， 可能是火山物質 。 '),
#  (0.72,
#   '該撞擊坑底可見暗色的弧型丘 ， 可能是中心環峯的殘餘 。 莫札特撞擊坑周圍的近距離調查發現有許多撞擊後形成撞擊坑期間 ， '
#   '撞擊噴發物撞擊表面形成的鏈狀次級撞擊坑 。 '),
#  (0.71, '桑德撞擊坑  是一個位於水星卡洛里盆地內的撞擊坑 。 它的撞擊坑壁是暗色區域 ， 而在它的底部有數個明亮區域 。 '),
#  (0.7,
#   '巴頓撞擊坑  是金星上一個直徑54 - 公里 ( 32 - 英里 ) 的撞擊坑 ， 它是指金星上始於峯形環的撞擊坑尺寸 ， '
#   '而不是僅單一中央峯的撞擊坑尺寸 。 巴頓撞擊坑的表面平坦且雷達反射較暗 ， 表明可能自撞擊坑形成後的某個時間 ， 已被熔岩流侵蝕充填 。 ')]
# [(0.88, '玲子·艾爾斯沃斯身上有西方血統與亞洲血統。'),
#  (0.86, '玲子·艾爾斯沃斯身上有歐洲血統與亞洲血統。'),
#  (0.81, '玲子·艾爾斯沃斯身上有英國血統與亞洲血統。')]
# [(0.82, '於1994年傳入臺灣的法輪功主要以口耳相傳介紹來介紹功法，是由中國傳入。'),
#  (0.78, '以口耳相傳介紹來介紹功法的法輪功在1994年從中國傳入臺灣。'),
#  (0.75, '於1994年傳入香港的法輪功主要以口耳相傳介紹來介紹功法，是由中國傳入。'),
#  (0.71, '是中華民國政府推廣的標準國語在臺灣經過數十年演變 ， 逐漸形成的臺灣在地化的華語口音 。 '),
#  (0.7,
#   '臺灣的語言學發展研究經過多位學者的整理 ， 歷經各個不同階段不同領域的一再重整 ， 終於在千頭萬緒中出現了具體的雛形 。 '
#   '第一次計劃性的全領域集結成書是竺家寧 （ 2000 ） 主編的 《 五十年來的中國語言學研究 》 。 '),
#  (0.69,
#   '中古漢語使用於魏晉 、 南北朝 、 隋朝 、 唐朝時期 ， 繼承自上古漢語 ， 後來發展爲近代漢語 。 南北朝 南北朝 隋朝 '
#   '隋朝現代語言學家根據當時的文獻資料重建出其特徵 。 '),
#  (0.68, '第一次計劃性的全領域集結成書是竺家寧 （ 2000 ） 主編的 《 五十年來的中國語言學研究 》 。 ')]
# [(0.98, '由文學作品改編的Kramer vs. Kramer 拿到了五項奧斯卡獎項。'),
#  (0.96, '由同名漫畫改編的Kramer vs. Kramer 拿到了五項奧斯卡獎項。'),
#  (0.94, '由新聞案件改編的Kramer vs. Kramer 拿到了五項奧斯卡獎項。'),
#  (0.85, '由同名小說改編的Kramer vs. Kramer 拿到了最佳原著改編獎。'),
#  (0.55,
#   '《 克萊默夫婦 》 （ Kramer vs. Kramer ） 是一部1979年的美國電影 ， 影片由羅伯特 · 本頓根據的同名小說改編並導演 ， '
#   '講述了一個家庭因妻子出走而發生的變故 ， 突出表現父親與兒子之間的感情 ， 深入反映了單親家庭的日常生活 ， '
#   '同時也對1970年代美國社會有一定程度的諷刺 。 美國電影 美國電影 美國社會 美國社會 導演 '
#   '學院獎最佳導演獎影片在第52屆奧斯卡獎角逐中獲得10項提名 ， 並最終拿下最佳影片 、 導演 、 最佳男主角 、 最佳女配角 、 最佳原著改編5項大獎 '
#   '。 第52屆奧斯卡獎 第52屆奧斯卡獎 最佳影片 學院獎最佳影片獎 導演 學院獎最佳導演獎 最佳男主角 學院獎最佳男主角獎 最佳女配角 '
#   '學院獎最佳女配角獎 最佳原著改編 學院獎最佳原著改編獎')]
# [(0.96, '研究地震波時，反射十分重要，通過對次聲波的檢測以研究地震與海嘯 。'),
#  (0.96, '研究地震波時，反射非常關鍵，通過對次聲波的檢測以研究地震與海嘯 。'),
#  (0.95, '地質學方面，反射在研究地震波時十分重要，通過對次聲波的檢測以研究地震與海嘯 。'),
#  (0.95, '研究潮汐時，反射十分重要，通過對次聲波的檢測以研究地震與海嘯 。'),
#  (0.86,
#   '地震波的性質 ， 來自於其母地震和傳播沿途的地質環境 ， 因此藉由研究地震波 ， 人類就有機會回推瞭解地震的起源與周遭的地質構造 ， 推進地震預警 、 '
#   '建築設計乃至於礦業工程的進展 。 換句話說 ， 研究地震波 ， 除了可以瞭解地震本身外 ， 還可以用來一窺地球內部堂奧 。 '),
#  (0.85,
#   '地震波的性質 ， 來自於其母地震和傳播沿途的地質環境 ， 因此藉由研究地震波 ， 人類就有機會回推瞭解地震的起源與周遭的地質構造 ， 推進地震預警 、 '
#   '建築設計乃至於礦業工程的進展 。 '),
#  (0.81,
#   '地震儀是種能夠偵測大地震動 、 探知地震發生 、 測繪地震波波形 ， 並輸出震波圖的儀器 。 當地震發生時 ， 人類除了肉體感知震動外 ， '
#   '如果要藉科學瞭解地震波具體的震動方式 、 震動方向 、 振動週期 ， 就得利用地震儀記錄地震波 。 '),
#  (0.81,
#   '地震學是一門研究地震以及震波在地球內部傳播的學問 ， 也研究其它由地震引起的現象 ， 如海嘯 ， 以及會引起地震的現象 ， 如板塊運動 、 火山運動等 '
#   '。')]
# [(0.83, '羅馬女神彌涅耳瓦被羅馬哲學家認爲是思想與宇宙命運的化身。'),
#  (0.82, '羅馬女神彌涅耳瓦被學者認爲是思想與宇宙命運的化身。'),
#  (0.77, '朱比特是古羅馬神話中統治宇宙至高無上的天神。')]
# [(0.99, '樂山大佛建造於唐朝而且花了90年。'),
#  (0.99, '樂山大佛建造於唐朝而且花了90年。'),
#  (0.99, '樂山大佛建造於唐朝而且花了90年。'),
#  (0.99, '樂山大佛建造於唐朝而且花了 90 年。'),
#  (0.72, '莫干山92號業主爲潘梓彝 。 92A建於1930年 ， 是一幢西式外廊建築 。 '),
#  (0.7,
#   '西林寺位於香港沙田區上禾輋村 ， 由原籍廣東南海的樑子衝在1923年建成 ， 至今有90餘年歷史 ， 萬佛寺創立者月溪法師也曾駐錫西林寺 。 '),
#  (0.67, '嘉佑寺 ， 位於中國廣東省惠州市橋東學背街 ， 爲惠州市的一個市 、 縣級文物保護單位 ， 類型爲古建築 ， 公佈時間爲1990年 。 '),
#  (0.67,
#   '表功牌坊 ， 位於中國廣東省惠州市橋西橋子頭 ， 爲惠州市的一個市 、 縣級文物保護單位 ， 類型爲古建築 ， 公佈時間爲1990年 。 ')]
# [(0.92, '韓劇挖掘人性之美、倡導傳統道家思想，是個適合家庭一起觀看的電視劇。'),
#  (0.89, '韓劇挖掘人性之美、倡導傳統儒家思想，是個適合家庭一起觀看的電視劇。'),
#  (0.86, '韓劇挖掘人性之美、倡導速食愛情，是個適合家庭一起觀看的電視劇。')]
# [(0.95, 'XBRL是一種基於可擴展標記語言的標記文法。'),
#  (0.88, 'XBRL是一種基於可擴展標記語言的標記語言，其標準制定與管理由XBRL國際聯合會負責。'),
#  (0.88, 'XBRL是一種基於美國語言的標記語言。'),
#  (0.87, 'XBRL是一種語言。'),
#  (0.76,
#   '可擴展商業報告語言 （ eXtensible Business Reporting Language ， XBRL ） 是一種基於XML的標記語言 ， '
#   '用於商業和財務訊息的定義和交換 。 XML XML 標記語言 標記語言XBRL標準的制定和管理由XBRL國際聯合會 （ XBRL '
#   'International ） 負責 。 '),
#  (0.74, 'XC是指令式語言 ， 基於了occam語言的並行和通信特徵 ， 和C語言的語法和順序特徵 。 '),
#  (0.74,
#   '可擴展樣式語言 （ Extensible Stylesheet Language , XSL ） ， 是一種爲可擴展置標語言 （ XML ） '
#   '提供表達形式而設計的計算機語言 。 可擴展置標語言 可擴展置標語言 計算機語言 計算機語言 XML XML'),
#  (0.74,
#   'XC是指令式語言 ， 基於了occam語言的並行和通信特徵 ， 和C語言的語法和順序特徵 。 它提供的根本特徵對應於現有架構的各種資源 ， 比如通道 '
#   '、 鎖和定時器 。 ')]
# [(0.87, '在1980年代初，史蒂夫·喬布斯使蘋果創造新技術加強了電腦的易用性和普及，離開蘋果公司後也成立了計算機動畫製片廠 。'),
#  (0.87, '離開蘋果公司後也成立了計算機動畫製片廠的史蒂夫·喬布斯，在1980年代初曾使蘋果引入新技術加強了電腦的易用性和普及。'),
#  (0.87, '在1980年代初，史蒂夫·喬布斯使蘋果引入新技術加強了電腦的易用性和普及，離開蘋果公司後也成立了計算機動畫製片廠 。'),
#  (0.87, '在1980年代初，史蒂夫·喬布斯使蘋果創造新技術加強了電腦的易用性和普及，離開蘋果公司後也搭建了計算機動畫製片廠 。'),
#  (0.73,
#   'Apple Lisa是1983年由蘋果電腦公司設計生產的一款個人電腦產品 ， 是全球第一款搭載圖形用戶界面 （ GUI ） 的商品化個人電腦 （ '
#   '但首臺圖形用戶介面電腦爲Xerox公司研發的內部產品 ） 。 '),
#  (0.71,
#   '是第一款成功的面向大衆市場的個人電腦 ， 它擁有圖形用戶界面 、 內置屏幕和鼠標 。 蘋果公司同時銷售其廣受歡迎的Apple '
#   'II系列電腦麥金塔電腦近十年 ， 直到Apple II於1993年停產 。 '),
#  (0.7,
#   '它的直系先祖是Apple I — — 一種有限的 、 以印刷電路板組成的電腦 。 許多電子玩家基於此電腦創新了許多功能 ， 使Apple '
#   'II達到商業上的成功 。 '),
#  (0.69,
#   '沃茲尼亞克的朋友史蒂夫 · 喬布斯則提出銷售這臺電腦的主意 。 Apple I是蘋果公司的第一項產品 ， 在1976年4月於加州帕羅奧圖的上展示 。 '
#   '蘋果公司 蘋果公司 帕羅奧圖 帕羅奧圖_(加利福尼亞州)')]

# %%
# 3. Label and Summarize [LS]

# %%
# !touch openai.env

# %%
# configure OpenAI API

load_dotenv('config.env')
load_dotenv('openai.env')
openai.api_key = getenv('OPENAI_API_KEY')
openai.organization = getenv('OPENAI_ORG_KEY')

print(f"OpenAI API is{' NOT' if not (openai.api_key and openai.organization) else ''} configured")

def openai_usage():
  end_date = date.today() + timedelta(days=1)
  start_date = date.today() + timedelta(days=-14)
  openai_total_usage = openai.api_requestor.APIRequestor().request('GET',
    f'/dashboard/billing/usage?start_date={start_date}&end_date={end_date}'
  )[0].data['total_usage'] / 100

  print(f'The usage of OpenAI API is US${openai_total_usage:.2f}, NT${openai_total_usage * 30.3:.1f} in the last 14 days')
# Out:
# OpenAI API is configured

# %%
# Use OpenAI to generate label for query's claim

def get_label_for_claim(
  claim: str,
  fact_claim: str,
  fact_label: Label,
  sleep_for_seconds: float = 0.15,
) -> Label:
  """
  ### prerequisites
  1. openai.api_key is set: OpenAI API key is a string in the form of `sk-***`
  2. openai.org_key is set: OpenAI Organization key is a string in the form of `org-***`

  ### return
  claim's label

  ### note
  Always return `'NOT ENOUGH INFO'` if `fact_label` == `'NOT ENOUGH INFO'`
  """

  if not openai.api_key:
    raise KeyError('openai.api_key should be set: OpenAI API key is in the form of `sk-***`')
  if not openai.organization:
    raise KeyError('openai.org_key should be set: OpenAI Organization key is in the form of `org-***`')

  if fact_label == 'NOT ENOUGH INFO':
    return 'NOT ENOUGH INFO'
  elif not (fact_label == 'supports' or fact_label == 'refutes'):
    raise TypeError("\
get_label_of_claim's paramter fact_label should be one of \
'supports', 'refutes', 'NOT ENOUGH INFO'"
    )

  # Get contextual similarity between claim and fact_claim from OpenAI's GPT API
  response = {}
  for chance in range(3):
    try:
      response = openai.ChatCompletion.create(
        model='gpt-3.5-turbo',
        messages=[
          {
            'role': 'system',
            'content': "(lang: zh-TW) assistant 將根據 system 提供的事實，判斷 user 的敘述是否正確",
          },
          {'role': 'system', 'content': fact_claim},
          {'role': 'user', 'content': claim},
          {
            'role': 'assistant',
            'content': "以下只能回復 1 個中文字，若 user 的敘述正確請回覆「是」，敘述錯誤則「否」，敘述與 system 提供之事實無關係則「沒」",
          },
        ],
        temperature=0.1,
        max_tokens=2,
        timeout=3,
      )
      break
    except:
      continue
  sleep(sleep_for_seconds)

  reply = response['choices'][0]['message']['content'].upper()
  usage = response['usage']['total_tokens']
  print(f"GPT-3.5 (Used {usage} tokens): {reply}")

  # process label
  if '是' in reply:
    return fact_label
  elif '否' in reply:
    if fact_label == 'supports':
      label_reversing_p = 0.9
      return _RNG_1.choice(
        ['refutes', 'supports'],
        p=[label_reversing_p, 1-label_reversing_p],
      )
    elif fact_label == 'refutes':
      label_reversing_p = 0.3
      return _RNG_1.choice(
        ['supports', 'NOT ENOUGH INFO'],
        p=[label_reversing_p, 1-label_reversing_p],
      )
  elif '沒' in reply:
    return 'NOT ENOUGH INFO'
  else:
    raise Exception(f'\
get_label_of_claim cannot recognize \
the reply from GPT-3.5: {reply}'
    )

def summarize(scores_labels: list[tuple[float, Label]]) -> Label:
  result: dict[Label, float] = {
    'supports': 0,
    'refutes': 0,
    'NOT ENOUGH INFO': 0,
  }
  for score, label in scores_labels:
    result[label] += (
      1 if label == 'NOT ENOUGH INFO' else score
    )

  if result['NOT ENOUGH INFO'] >= len(scores_labels) / 2:
    return 'NOT ENOUGH INFO'
  return max([(v, k) for k, v in result.items()])[1]

# %%
submissions: list[Submission] = []

for query_id, query_claim in list(queries.items())[:90]: # [DEV]
  scores_labels: list[tuple[float, Label]] = []
  answers: list[Answer] = []

  for score, answer in candicates[query_id]:
    scores_labels.append((
      score,
      get_label_for_claim(
        query_claim,
        answer['claim'],
        answer['label'],
      )
    ))
    answers.append(answer)

  label = summarize(scores_labels)
  evidence: list[Evidence] = list(set(
    tuple(evidence)
    for answer in filter(
      lambda a: (
        (a['label'] != 'NOT ENOUGH INFO') if label == 'refutes' else
        (a['label'] == label)
      ),
      answers
    )
      for evidence in answer['evidences']
  ))[:5]

  submissions.append({
    'id': query_id,
    'predicted_label': label,
    'predicted_evidence': evidence if evidence else None,
    'claim': query_claim,
  })

openai_usage()
# Out:
# GPT-3.5 (Used 227 tokens): 否
# GPT-3.5 (Used 292 tokens): 否
# GPT-3.5 (Used 299 tokens): 沒
# GPT-3.5 (Used 327 tokens): 是。
# GPT-3.5 (Used 273 tokens): 否
# GPT-3.5 (Used 207 tokens): 是
# GPT-3.5 (Used 222 tokens): 是。
# GPT-3.5 (Used 228 tokens): 是
# GPT-3.5 (Used 193 tokens): 否
# GPT-3.5 (Used 198 tokens): 否
# GPT-3.5 (Used 191 tokens): 否
# GPT-3.5 (Used 176 tokens): 否
# GPT-3.5 (Used 177 tokens): 否
# GPT-3.5 (Used 176 tokens): 否
# GPT-3.5 (Used 215 tokens): 是
# GPT-3.5 (Used 215 tokens): 是
# GPT-3.5 (Used 219 tokens): 是
# GPT-3.5 (Used 219 tokens): 否
# GPT-3.5 (Used 574 tokens): 否
# GPT-3.5 (Used 215 tokens): 否
# GPT-3.5 (Used 211 tokens): 否
# GPT-3.5 (Used 300 tokens): 否
# GPT-3.5 (Used 207 tokens): 否
# GPT-3.5 (Used 208 tokens): 否
# GPT-3.5 (Used 202 tokens): 否
# GPT-3.5 (Used 178 tokens): 是。
# GPT-3.5 (Used 192 tokens): 是
# GPT-3.5 (Used 247 tokens): 是
# GPT-3.5 (Used 229 tokens): 是
# GPT-3.5 (Used 217 tokens): 是
# GPT-3.5 (Used 217 tokens): 是
# GPT-3.5 (Used 217 tokens): 是
# GPT-3.5 (Used 217 tokens): 是
# GPT-3.5 (Used 417 tokens): 是
# GPT-3.5 (Used 201 tokens): 是
# GPT-3.5 (Used 201 tokens): 是
# GPT-3.5 (Used 451 tokens): 是
# GPT-3.5 (Used 225 tokens): 否
# GPT-3.5 (Used 230 tokens): 是
# GPT-3.5 (Used 224 tokens): 沒
# GPT-3.5 (Used 288 tokens): 否
# GPT-3.5 (Used 289 tokens): 是
# GPT-3.5 (Used 284 tokens): 否
# GPT-3.5 (Used 235 tokens): 是
# GPT-3.5 (Used 234 tokens): 是
# GPT-3.5 (Used 234 tokens): 否。
# GPT-3.5 (Used 272 tokens): 是
# GPT-3.5 (Used 313 tokens): 是
# GPT-3.5 (Used 265 tokens): 是
# GPT-3.5 (Used 356 tokens): 是
# GPT-3.5 (Used 198 tokens): 否
# GPT-3.5 (Used 200 tokens): 否
# GPT-3.5 (Used 199 tokens): 否
# GPT-3.5 (Used 234 tokens): 是。
# GPT-3.5 (Used 225 tokens): 是
# GPT-3.5 (Used 233 tokens): 是
# GPT-3.5 (Used 249 tokens): 否
# GPT-3.5 (Used 332 tokens): 沒
# GPT-3.5 (Used 306 tokens): 否
# GPT-3.5 (Used 244 tokens): 否
# GPT-3.5 (Used 199 tokens): 是
# GPT-3.5 (Used 200 tokens): 是
# GPT-3.5 (Used 199 tokens): 是
# GPT-3.5 (Used 198 tokens): 是
# GPT-3.5 (Used 608 tokens): 是
# GPT-3.5 (Used 235 tokens): 否
# GPT-3.5 (Used 238 tokens): 否
# GPT-3.5 (Used 243 tokens): 否
# GPT-3.5 (Used 371 tokens): 否
# GPT-3.5 (Used 317 tokens): 否
# GPT-3.5 (Used 344 tokens): 否
# GPT-3.5 (Used 281 tokens): 否
# GPT-3.5 (Used 220 tokens): 否
# GPT-3.5 (Used 210 tokens): 沒
# GPT-3.5 (Used 175 tokens): 是
# GPT-3.5 (Used 175 tokens): 是
# GPT-3.5 (Used 175 tokens): 是
# GPT-3.5 (Used 178 tokens): 是。
# GPT-3.5 (Used 199 tokens): 否
# GPT-3.5 (Used 250 tokens): 否
# GPT-3.5 (Used 240 tokens): 否
# GPT-3.5 (Used 238 tokens): 否
# GPT-3.5 (Used 232 tokens): 是
# GPT-3.5 (Used 234 tokens): 是
# GPT-3.5 (Used 228 tokens): 是
# GPT-3.5 (Used 186 tokens): 是。
# GPT-3.5 (Used 215 tokens): 是。
# GPT-3.5 (Used 181 tokens): 是。
# GPT-3.5 (Used 166 tokens): 是
# GPT-3.5 (Used 277 tokens): 是。
# GPT-3.5 (Used 207 tokens): 沒
# GPT-3.5 (Used 272 tokens): 是。
# GPT-3.5 (Used 258 tokens): 沒
# GPT-3.5 (Used 318 tokens): 是
# GPT-3.5 (Used 318 tokens): 否
# GPT-3.5 (Used 317 tokens): 是
# GPT-3.5 (Used 320 tokens): 是
# GPT-3.5 (Used 354 tokens): 是
# GPT-3.5 (Used 356 tokens): 是
# GPT-3.5 (Used 326 tokens): 是
# GPT-3.5 (Used 370 tokens): 是
# GPT-3.5 (Used 248 tokens): 否
# GPT-3.5 (Used 316 tokens): 沒
# GPT-3.5 (Used 270 tokens): 否
# GPT-3.5 (Used 527 tokens): 沒
# GPT-3.5 (Used 182 tokens): 是。
# GPT-3.5 (Used 185 tokens): 是。
# GPT-3.5 (Used 182 tokens): 是
# GPT-3.5 (Used 186 tokens): 是
# GPT-3.5 (Used 251 tokens): 是
# GPT-3.5 (Used 219 tokens): 是
# GPT-3.5 (Used 192 tokens): 沒
# GPT-3.5 (Used 192 tokens): 是。
# GPT-3.5 (Used 220 tokens): 是
# GPT-3.5 (Used 224 tokens): 是
# GPT-3.5 (Used 257 tokens): 否
# GPT-3.5 (Used 545 tokens): 沒
# GPT-3.5 (Used 249 tokens): 沒
# GPT-3.5 (Used 349 tokens): 沒
# GPT-3.5 (Used 349 tokens): 沒
# GPT-3.5 (Used 261 tokens): 是
# GPT-3.5 (Used 255 tokens): 否
# GPT-3.5 (Used 277 tokens): 是
# GPT-3.5 (Used 277 tokens): 是
# GPT-3.5 (Used 285 tokens): 否
# GPT-3.5 (Used 244 tokens): 是
# GPT-3.5 (Used 328 tokens): 是
# GPT-3.5 (Used 404 tokens): 是
# GPT-3.5 (Used 220 tokens): 是
# GPT-3.5 (Used 225 tokens): 否
# GPT-3.5 (Used 219 tokens): 否
# GPT-3.5 (Used 192 tokens): 是。
# GPT-3.5 (Used 188 tokens): 是
# GPT-3.5 (Used 244 tokens): 否
# GPT-3.5 (Used 225 tokens): 否
# GPT-3.5 (Used 243 tokens): 是
# GPT-3.5 (Used 272 tokens): 否
# GPT-3.5 (Used 222 tokens): 否
# GPT-3.5 (Used 221 tokens): 否
# GPT-3.5 (Used 196 tokens): 是
# GPT-3.5 (Used 191 tokens): 否
# GPT-3.5 (Used 187 tokens): 否
# GPT-3.5 (Used 183 tokens): 沒
# GPT-3.5 (Used 208 tokens): 是
# GPT-3.5 (Used 336 tokens): 是
# GPT-3.5 (Used 307 tokens): 沒
# GPT-3.5 (Used 233 tokens): 是。
# GPT-3.5 (Used 240 tokens): 是
# GPT-3.5 (Used 239 tokens): 是
# GPT-3.5 (Used 174 tokens): 否
# GPT-3.5 (Used 265 tokens): 否
# GPT-3.5 (Used 216 tokens): 否
# GPT-3.5 (Used 231 tokens): 是
# GPT-3.5 (Used 228 tokens): 是
# GPT-3.5 (Used 339 tokens): 是
# GPT-3.5 (Used 467 tokens): 是
# GPT-3.5 (Used 205 tokens): 否
# GPT-3.5 (Used 204 tokens): 否
# GPT-3.5 (Used 206 tokens): 否
# GPT-3.5 (Used 205 tokens): 否
# GPT-3.5 (Used 211 tokens): 否
# GPT-3.5 (Used 356 tokens): 否
# GPT-3.5 (Used 183 tokens): 沒
# GPT-3.5 (Used 417 tokens): 否
# GPT-3.5 (Used 223 tokens): 沒
# GPT-3.5 (Used 217 tokens): 否
# GPT-3.5 (Used 191 tokens): 沒
# GPT-3.5 (Used 224 tokens): 沒
# GPT-3.5 (Used 224 tokens): 沒
# GPT-3.5 (Used 291 tokens): 是
# GPT-3.5 (Used 308 tokens): 是
# GPT-3.5 (Used 276 tokens): 是
# GPT-3.5 (Used 432 tokens): 沒
# GPT-3.5 (Used 213 tokens): 否
# GPT-3.5 (Used 214 tokens): 否
# GPT-3.5 (Used 226 tokens): 沒
# GPT-3.5 (Used 241 tokens): 沒
# GPT-3.5 (Used 217 tokens): 沒
# GPT-3.5 (Used 508 tokens): 否
# GPT-3.5 (Used 203 tokens): 否
# GPT-3.5 (Used 339 tokens): 是。
# GPT-3.5 (Used 233 tokens): 是
# GPT-3.5 (Used 203 tokens): 是
# GPT-3.5 (Used 205 tokens): 是
# GPT-3.5 (Used 267 tokens): 是
# GPT-3.5 (Used 205 tokens): 是。
# GPT-3.5 (Used 327 tokens): 是。
# GPT-3.5 (Used 178 tokens): 是。
# GPT-3.5 (Used 184 tokens): 否
# GPT-3.5 (Used 184 tokens): 否
# GPT-3.5 (Used 399 tokens): 否
# GPT-3.5 (Used 310 tokens): 否
# GPT-3.5 (Used 213 tokens): 否
# GPT-3.5 (Used 222 tokens): 否
# GPT-3.5 (Used 213 tokens): 否
# GPT-3.5 (Used 215 tokens): 否
# GPT-3.5 (Used 212 tokens): 否
# GPT-3.5 (Used 219 tokens): 否
# GPT-3.5 (Used 215 tokens): 否
# GPT-3.5 (Used 299 tokens): 否
# GPT-3.5 (Used 156 tokens): 是
# GPT-3.5 (Used 155 tokens): 是
# GPT-3.5 (Used 161 tokens): 是
# GPT-3.5 (Used 283 tokens): 否
# GPT-3.5 (Used 283 tokens): 否
# GPT-3.5 (Used 283 tokens): 否
# GPT-3.5 (Used 283 tokens): 否
# GPT-3.5 (Used 277 tokens): 沒
# GPT-3.5 (Used 275 tokens): 沒
# GPT-3.5 (Used 286 tokens): 沒
# GPT-3.5 (Used 254 tokens): 沒
# GPT-3.5 (Used 265 tokens): 否
# GPT-3.5 (Used 266 tokens): 否
# GPT-3.5 (Used 265 tokens): 否
# GPT-3.5 (Used 268 tokens): 是
# GPT-3.5 (Used 256 tokens): 是
# GPT-3.5 (Used 248 tokens): 否
# GPT-3.5 (Used 285 tokens): 沒
# GPT-3.5 (Used 174 tokens): 是
# GPT-3.5 (Used 178 tokens): 是
# GPT-3.5 (Used 199 tokens): 否
# GPT-3.5 (Used 197 tokens): 沒
# GPT-3.5 (Used 212 tokens): 否。
# GPT-3.5 (Used 211 tokens): 否
# GPT-3.5 (Used 319 tokens): 否
# GPT-3.5 (Used 313 tokens): 否
# GPT-3.5 (Used 315 tokens): 否
# GPT-3.5 (Used 234 tokens): 否
# GPT-3.5 (Used 233 tokens): 否
# GPT-3.5 (Used 174 tokens): 是。
# GPT-3.5 (Used 172 tokens): 是。
# GPT-3.5 (Used 170 tokens): 是
# GPT-3.5 (Used 218 tokens): 否
# GPT-3.5 (Used 210 tokens): 否
# GPT-3.5 (Used 248 tokens): 是
# GPT-3.5 (Used 324 tokens): 是
# GPT-3.5 (Used 322 tokens): 是
# GPT-3.5 (Used 324 tokens): 否
# GPT-3.5 (Used 323 tokens): 是
# GPT-3.5 (Used 371 tokens): 是
# GPT-3.5 (Used 328 tokens): 是
# GPT-3.5 (Used 368 tokens): 是
# GPT-3.5 (Used 256 tokens): 是
# GPT-3.5 (Used 213 tokens): 否
# GPT-3.5 (Used 214 tokens): 是
# GPT-3.5 (Used 215 tokens): 否
# GPT-3.5 (Used 219 tokens): 是
# GPT-3.5 (Used 213 tokens): 是
# GPT-3.5 (Used 223 tokens): 否
# GPT-3.5 (Used 298 tokens): 否
# GPT-3.5 (Used 250 tokens): 是
# GPT-3.5 (Used 315 tokens): 是
# GPT-3.5 (Used 256 tokens): 否
# GPT-3.5 (Used 365 tokens): 否
# GPT-3.5 (Used 257 tokens): 沒
# GPT-3.5 (Used 252 tokens): 否
# GPT-3.5 (Used 251 tokens): 否
# GPT-3.5 (Used 254 tokens): 否
# GPT-3.5 (Used 261 tokens): 否
# GPT-3.5 (Used 376 tokens): 否
# GPT-3.5 (Used 310 tokens): 否
# GPT-3.5 (Used 477 tokens): 是
# GPT-3.5 (Used 287 tokens): 否
# GPT-3.5 (Used 220 tokens): 否
# GPT-3.5 (Used 220 tokens): 否
# GPT-3.5 (Used 226 tokens): 否
# GPT-3.5 (Used 239 tokens): 否
# GPT-3.5 (Used 241 tokens): 否
# GPT-3.5 (Used 272 tokens): 否
# GPT-3.5 (Used 293 tokens): 否
# GPT-3.5 (Used 294 tokens): 否
# GPT-3.5 (Used 237 tokens): 否
# GPT-3.5 (Used 244 tokens): 是
# GPT-3.5 (Used 301 tokens): 是
# GPT-3.5 (Used 247 tokens): 是
# GPT-3.5 (Used 342 tokens): 沒
# GPT-3.5 (Used 279 tokens): 否
# GPT-3.5 (Used 226 tokens): 是
# GPT-3.5 (Used 227 tokens): 是
# GPT-3.5 (Used 239 tokens): 否
# GPT-3.5 (Used 227 tokens): 否
# GPT-3.5 (Used 299 tokens): 是
# GPT-3.5 (Used 293 tokens): 是
# GPT-3.5 (Used 443 tokens): 是
# GPT-3.5 (Used 337 tokens): 否
# GPT-3.5 (Used 326 tokens): 否
# GPT-3.5 (Used 302 tokens): 是
# GPT-3.5 (Used 278 tokens): 是
# GPT-3.5 (Used 278 tokens): 是
# GPT-3.5 (Used 277 tokens): 是
# GPT-3.5 (Used 280 tokens): 是
# GPT-3.5 (Used 347 tokens): 沒
# GPT-3.5 (Used 359 tokens): 沒
# GPT-3.5 (Used 524 tokens): 是
# GPT-3.5 (Used 394 tokens): 沒
# GPT-3.5 (Used 173 tokens): 否
# GPT-3.5 (Used 180 tokens): 是
# GPT-3.5 (Used 225 tokens): 是。
# GPT-3.5 (Used 331 tokens): 沒
# GPT-3.5 (Used 262 tokens): 否
# GPT-3.5 (Used 281 tokens): 沒
# GPT-3.5 (Used 212 tokens): 否
# GPT-3.5 (Used 228 tokens): 否
# GPT-3.5 (Used 283 tokens): 沒
# GPT-3.5 (Used 230 tokens): 沒
# GPT-3.5 (Used 231 tokens): 否
# GPT-3.5 (Used 243 tokens): 否
# GPT-3.5 (Used 241 tokens): 否
# GPT-3.5 (Used 269 tokens): 否
# GPT-3.5 (Used 325 tokens): 是
# GPT-3.5 (Used 327 tokens): 沒
# GPT-3.5 (Used 253 tokens): 沒
# GPT-3.5 (Used 204 tokens): 是
# GPT-3.5 (Used 207 tokens): 是。
# GPT-3.5 (Used 231 tokens): 是
# GPT-3.5 (Used 198 tokens): 是。
# GPT-3.5 (Used 233 tokens): 沒
# GPT-3.5 (Used 267 tokens): 沒
# GPT-3.5 (Used 238 tokens): 是
# GPT-3.5 (Used 230 tokens): 沒
# GPT-3.5 (Used 239 tokens): 否
# GPT-3.5 (Used 275 tokens): 否
# GPT-3.5 (Used 323 tokens): 否
# GPT-3.5 (Used 321 tokens): 否
# GPT-3.5 (Used 338 tokens): 否
# GPT-3.5 (Used 291 tokens): 否
# GPT-3.5 (Used 295 tokens): 否
# GPT-3.5 (Used 287 tokens): 否
# GPT-3.5 (Used 288 tokens): 是
# GPT-3.5 (Used 288 tokens): 是
# GPT-3.5 (Used 243 tokens): 是
# GPT-3.5 (Used 243 tokens): 是
# GPT-3.5 (Used 329 tokens): 沒
# GPT-3.5 (Used 364 tokens): 是
# GPT-3.5 (Used 321 tokens): 是。
# GPT-3.5 (Used 317 tokens): 是
# GPT-3.5 (Used 270 tokens): 是
# GPT-3.5 (Used 335 tokens): 是
# GPT-3.5 (Used 336 tokens): 是
# GPT-3.5 (Used 327 tokens): 是
# GPT-3.5 (Used 170 tokens): 是。
# GPT-3.5 (Used 169 tokens): 否
# GPT-3.5 (Used 172 tokens): 是。
# GPT-3.5 (Used 172 tokens): 是。
# GPT-3.5 (Used 216 tokens): 是。
# GPT-3.5 (Used 179 tokens): 沒
# GPT-3.5 (Used 223 tokens): 是
# GPT-3.5 (Used 216 tokens): 是
# GPT-3.5 (Used 205 tokens): 否
# GPT-3.5 (Used 200 tokens): 是
# GPT-3.5 (Used 204 tokens): 否
# GPT-3.5 (Used 207 tokens): 否
# GPT-3.5 (Used 271 tokens): 是
# GPT-3.5 (Used 240 tokens): 否
# GPT-3.5 (Used 229 tokens): 是
# GPT-3.5 (Used 222 tokens): 是
# GPT-3.5 (Used 177 tokens): 否
# GPT-3.5 (Used 180 tokens): 否
# GPT-3.5 (Used 177 tokens): 否
# GPT-3.5 (Used 187 tokens): 否。
# GPT-3.5 (Used 190 tokens): 否。
# GPT-3.5 (Used 190 tokens): 否
# GPT-3.5 (Used 194 tokens): 否
# GPT-3.5 (Used 191 tokens): 否
# GPT-3.5 (Used 188 tokens): 否
# GPT-3.5 (Used 191 tokens): 是
# GPT-3.5 (Used 191 tokens): 否
# GPT-3.5 (Used 195 tokens): 是
# GPT-3.5 (Used 189 tokens): 是
# GPT-3.5 (Used 184 tokens): 否
# GPT-3.5 (Used 183 tokens): 沒
# GPT-3.5 (Used 191 tokens): 否
# GPT-3.5 (Used 183 tokens): 否
# GPT-3.5 (Used 184 tokens): 沒
# GPT-3.5 (Used 182 tokens): 沒
# GPT-3.5 (Used 247 tokens): 沒
# GPT-3.5 (Used 322 tokens): 否
# GPT-3.5 (Used 364 tokens): 否
# GPT-3.5 (Used 274 tokens): 沒
# GPT-3.5 (Used 198 tokens): 否
# GPT-3.5 (Used 200 tokens): 否
# GPT-3.5 (Used 219 tokens): 沒
# GPT-3.5 (Used 298 tokens): 沒
# GPT-3.5 (Used 263 tokens): 沒
# GPT-3.5 (Used 256 tokens): 否
# GPT-3.5 (Used 233 tokens): 是。
# GPT-3.5 (Used 228 tokens): 是
# GPT-3.5 (Used 234 tokens): 否
# GPT-3.5 (Used 231 tokens): 否
# GPT-3.5 (Used 241 tokens): 沒
# GPT-3.5 (Used 344 tokens): 是。
# GPT-3.5 (Used 232 tokens): 是。
# GPT-3.5 (Used 232 tokens): 是。
# GPT-3.5 (Used 414 tokens): 沒
# GPT-3.5 (Used 188 tokens): 否
# GPT-3.5 (Used 193 tokens): 否
# GPT-3.5 (Used 272 tokens): 否
# GPT-3.5 (Used 189 tokens): 否
# GPT-3.5 (Used 176 tokens): 是
# GPT-3.5 (Used 178 tokens): 否
# GPT-3.5 (Used 181 tokens): 是
# GPT-3.5 (Used 180 tokens): 是
# GPT-3.5 (Used 208 tokens): 否
# GPT-3.5 (Used 276 tokens): 否
# GPT-3.5 (Used 186 tokens): 是
# GPT-3.5 (Used 215 tokens): 否
# GPT-3.5 (Used 246 tokens): 否
# GPT-3.5 (Used 340 tokens): 否
# GPT-3.5 (Used 207 tokens): 沒
# GPT-3.5 (Used 322 tokens): 沒
# GPT-3.5 (Used 268 tokens): 否
# GPT-3.5 (Used 272 tokens): 沒
# GPT-3.5 (Used 192 tokens): 否
# GPT-3.5 (Used 188 tokens): 否
# GPT-3.5 (Used 236 tokens): 是
# GPT-3.5 (Used 237 tokens): 否
# GPT-3.5 (Used 259 tokens): 否
# GPT-3.5 (Used 167 tokens): 沒
# GPT-3.5 (Used 376 tokens): 沒
# GPT-3.5 (Used 201 tokens): 沒
# GPT-3.5 (Used 264 tokens): 是
# GPT-3.5 (Used 262 tokens): 是
# GPT-3.5 (Used 263 tokens): 是
# GPT-3.5 (Used 265 tokens): 是
# GPT-3.5 (Used 333 tokens): 是
# GPT-3.5 (Used 414 tokens): 是
# GPT-3.5 (Used 269 tokens): 是
# GPT-3.5 (Used 368 tokens): 是
# GPT-3.5 (Used 215 tokens): 沒
# GPT-3.5 (Used 296 tokens): 是
# GPT-3.5 (Used 285 tokens): 是
# GPT-3.5 (Used 293 tokens): 是
# GPT-3.5 (Used 221 tokens): 沒
# GPT-3.5 (Used 299 tokens): 沒
# GPT-3.5 (Used 227 tokens): 沒
# GPT-3.5 (Used 221 tokens): 沒
# GPT-3.5 (Used 206 tokens): 是
# GPT-3.5 (Used 219 tokens): 是
# GPT-3.5 (Used 208 tokens): 是
# GPT-3.5 (Used 192 tokens): 是
# GPT-3.5 (Used 234 tokens): 沒
# GPT-3.5 (Used 203 tokens): 否
# GPT-3.5 (Used 295 tokens): 否
# GPT-3.5 (Used 223 tokens): 是
# GPT-3.5 (Used 262 tokens): 否
# GPT-3.5 (Used 262 tokens): 否
# GPT-3.5 (Used 263 tokens): 否
# GPT-3.5 (Used 256 tokens): 否
# GPT-3.5 (Used 312 tokens): 是
# GPT-3.5 (Used 312 tokens): 沒
# GPT-3.5 (Used 385 tokens): 沒
# GPT-3.5 (Used 328 tokens): 沒
# GPT-3.5 (Used 165 tokens): 是
# GPT-3.5 (Used 174 tokens): 沒
# GPT-3.5 (Used 171 tokens): 否
# GPT-3.5 (Used 196 tokens): 是
# GPT-3.5 (Used 193 tokens): 否
# GPT-3.5 (Used 195 tokens): 是
# The usage of OpenAI API is US$0.48, NT$14.6 in the last 14 days

# %%
for query in list(queries.items())[:90]: # [DEV]
  print(query)
# Out:
# (5208, '光學顯微鏡是以電磁學原理來將不可見或難見的微小物放大至肉眼可見的儀器。')
# (1019, '產絲的蠶或產蜜的蜜蜂爲提供間接經濟利益的昆蟲。')
# (8514, '波蘭西部的綠山城縣平均每平方公里的土地有0人。')
# (1874, 'Vivien Leigh主演魂斷藍橋中的女配角。')
# (8352, '侯孝賢改編自唐代文言文學的電影獲得金馬獎最佳劇情片獎。')
# (4603, '國務院前副總理的姪子薄熙來在2012年9月被開除黨籍 。')
# (3147, '水星凌日曾發生過。')
# (5829, '馬克思在自己的作品中論述了馬克思主義政治經濟學的基本概念。')
# (2656, '一貫道相信最高神祇無生老母派遣轉世成銀公祖師路中一的彌勒佛拯救凡間。')
# (3887, '回族世居內蒙古至山西 、 陝西 、 甘肅 ， 以至於新疆和中亞一帶，受中亞與西亞中伊斯蘭教傳播的影響 ， 許多回族成爲穆斯林。')
# (2268, '天衛四的表面呈現暗紅色，小行星和彗星相撞後所形成其主要地形，並存在許多撞擊坑。')
# (7468, '玲子·艾爾斯沃斯身上有美洲血統與亞洲血統。')
# (9045, '於西元2000年以前傳入臺灣的法輪功主要以口耳相傳介紹來介紹功法，是由中國傳入。')
# (3693, '由同名小說改編的Kramer vs. Kramer 拿到了五項奧斯卡獎項。')
# (4173, '研究地震波時，反射十分重要，通過對海浪形狀的檢測以研究地震與海嘯 。')
# (3289, '思想與宇宙命運被學者認爲屬於彌涅耳瓦以外的羅馬神祇所化身。')
# (133, '樂山大佛建造於唐朝而且花了90年。')
# (2722, '韓劇挖掘人性之真善美、倡導仁、誠、恕，是個適合家庭一起觀看的電視劇。')
# (1838, '基於可擴展標記語言的標記語言是XBRL。')
# (3395, '在1980年代初，史蒂夫·喬布斯使蘋果引入全錄帕洛奧圖中心 （ Xerox PARC ） 的滑鼠驅動圖形用戶介面技術加強了電腦的易用性和普及，離開蘋果公司後也成立了計算機動畫製片廠 。')
# (5437, '「211工程」中唯一的政法類高校的中國政法大學沒有隸屬於直屬機關下，而是獨立運作的私人大學。')
# (4278, '珠江三角洲範圍包括珠江干流。')
# (663, '亞伯拉罕諸教爲基督宗教、伊斯蘭教與猶太教的通則。')
# (5583, '意大利威尼斯影展頒發給最佳影片的首獎從1949年開始稱作金獅獎，是電影界最高榮譽之一。')
# (5237, '對日民間索賠的類型包含二戰後幾十年因遺留的炸彈造成傷害的賠償。')
# (8329, '汾河是山西人的母親河，其上游是太原市主要水來源。')
# (1766, '東帝汶在澳洲等地區的支持下通過電影決定獨立後，於2002年真正獨立。')
# (3915, '普京在1999年的最後一天從總理成爲代理部長。')
# (3108, '位於阿拉伯半島東南沿海的阿曼蘇丹國南部和東部臨印度洋。')
# (3042, '傳說有一位北歐神明索爾，會在雷雨交加時乘坐交通工具巡視人間。')
# (909, '行政法與政府行政部門的決策活動關係疏遠。')
# (3225, '英國第一個由國家成立的廣播機構是BBC，文化傳媒與體育大臣負責監管。')
# (1109, '戰爭與和平是俄國作家列夫 · 托爾斯泰的一條函數。')
# (659, '燕山大學，簡稱燕大，一隻位在中國河北省秦皇島市的鱷魚。')
# (4735, '韓國政治家高建的社會評價充斥著負面訊息。')
# (641, '懷化市，別稱鶴城、五溪，是中華人民共和國湖北省下轄的地級市。')
# (4750, '螺旋動物，又稱螺旋卵裂動物，是原口動物的一大分支。')
# (6073, '六和敬指6種需要遵循的生活態度，是佛教術語。')
# (6689, '卡夫卡的短篇故事合集在他在世時出版。')
# (5380, '金朝以 “ 大金 ” 爲口號是因爲皇帝希望國府永遠不變不壞。')
# (5418, 'iPod mini的物理量比iPod輕。')
# (1250, '歐洲民族中各個民族基本是以手指數量劃分，同國家的同一手指數量的人群承認屬於同一族群，也有人更願意強調自己的腳趾。')
# (8943, '兒玉利國 ， 日本鹿兒島縣人 ， 爲明治時代官員 ， 日軍海軍的少將，他謝絕參與牡丹社的調查活動 。')
# (4898, '朱棣文曾在斯坦福大學授教。')
# (6456, '威廉·華茲華斯是生活在蘇格蘭湖區的詩人代表。')
# (3877, '身爲晚清進士的沈鈞儒，祖籍在嘉興，是江蘇省蘇州人。')
# (4920, '皮特·烏斯蒂諾夫爵士有瑞士、埃塞俄比亞、意大利以及法國的血統，在1990年被法國女王伊麗莎白二世授予爵士稱號，曾兩次榮獲奧斯卡獎。')
# (5996, '最流行的《 毛主席語錄 》 禁止使用波長大約爲630到750nm的可見光色作爲顏色。')
# (1179, '普路託是羅馬神話中陰間的主宰。')
# (3784, '以高性能纖維爲增強材料的複合材料被大量運用到航空航天行業，爲了與第一代玻璃纖維增強樹脂複合材料相區別，稱作先進複合材料。')
# (8921, '第七號交響曲的標題晨之歌不是由奧地利作曲家馬勒所命名的。')
# (3087, '於1982年與山下達郎結婚的竹內瑪莉亞，當初是以偶像歌手身分出道。')
# (6616, '經濟學家楊小凱提出了新興古典經濟學與超邊際分析方法和理論，曾是哈佛大學客座教授。')
# (3828, '1917年俄羅斯人亞歷山大·克倫斯基阻止了民主革命推翻了沙皇的統治，卻在同年又被推翻。')
# (3058, '韓國行政道全羅北道的首府在聯合國教科文組織指定的美食城市之一賓州。')
# (493, '伍迪·艾倫對於演一些不安的 、 煩躁的以及帶有神經質的角色相當反感且不熟悉。')
# (485, '在 2004 年，時代雜誌將伍迪·艾倫評爲百大滑稽演員 （ stand up comics ） 第四位。')
# (4025, '醋一般按造購買方式可分爲釀造醋等共三種種類，釀造醋是以穀類等天然原料爲主 ， 再加上食鹽 、 穀皮等發酵而成的食醋 。')
# (5568, '食鹽、芒硝、石油和天然氣豐富的卡拉卡爾帕克斯坦共和國，屬於突厥語族，居民是卡拉卡爾帕克族人。')
# (950, '鎖麟囊頒獎在上海黃金戲院。')
# (6126, '臺北市士林區華岡藝校的創始人爲前教育部部長張其昀。')
# (5458, '俗稱電石氣的炔烴化合物乙炔，聚合生成乙烯基乙炔和苯需要遠高於攝氏400度以上。')
# (5692, '康托爾死後數十年，大多數數學家已經接受他的理論。')
# (4245, '印度佛教史中的根本分裂是指上座部與大衆部的教派分裂，其原因是喫素議題紛爭。')
# (4852, '受章回小說《 三國演義 》的影響普遍認爲關羽與劉備 、 趙子龍義結金蘭，因此排行第二的關羽又稱關二爺。')
# (4539, '一般線性群中典型符號是 GLn(F)或GL ( n, F ) ，而群 GL ( n, F ) 和它的子群經常叫做線性群或矩陣群，在群表示理論中引發對空間對稱和一般向量空間對稱的研究，有很重要的地位。')
# (2045, '土衛十一是木星的一顆內側衛星。')
# (3837, '墨家邏輯是一個邏輯學體系，主要以三物論爲代表。')
# (8153, '高安公寓在上海康平路1號公寓對面3公尺。')
# (3556, '流產是指胚胎或胎兒發育到之前發生基因突變 。')
# (8717, '氫氣雙原子分子鍵長約74皮米。')
# (819, '弗拉基米爾·普京於2008年卸任總統後退休。')
# (9036, '中國南北朝時舉行的崇義郡位於現今的湖北省。')
# (831, '愛爾蘭的體積約爲七萬平方公里。')
# (5121, '臺北市萬華區老松安養院是臺北市的指定古蹟建築。')
# (5592, '世界上第四大耕作水源的大麥是一種禾本科植物，起源於可在中東發現的野生大麥，有別稱三月黃。')
# (1617, '屬是生物學分類學中的一個形容詞，用於生物學中的生物和化石生物以及病毒的生物分類。')
# (5283, '荷馬史詩確定是由來自美洲詩人所創作的。')
# (2172, '南京大學附屬中學，位於中國江蘇省 。')
# (4333, '科隆在二十世紀後期農業佔大宗。')
# (7737, '勇度是漫威多格漫畫中藍色皮膚的虛構人物。')
# (7793, '臺南市美術館僅有一棟場館建築位於臺南市中西區。')
# (4902, '朱棣文曾在泰國大學當老師。')
# (8431, '利用澱粉水解、發酵產生糖分後製成的酒精飲料稱爲啤酒，啤酒釀造工業已具有全球性。')
# (539, '不可否認的是 ， 該工程對人們瞭解與研究中國上古歷史有極其重要的參考價值 。')
# (422, '良好的代碼風格可以幫助程序員早睡早起。')
# (2375, '華南理工大學曾名華南工學院，是中華人民共和國頂尖高校之一。')
# (5869, '由於日本的教育裝備與物資皆遜於盟軍，因此發展出特別攻擊隊以最少資源獲取最大破壞力。')
# (187, '尼克·貝爾格自2004年失蹤')
# (7314, '臺灣最高峯所在的南投縣，擁有水果、酒、茶等特產。')

# %%
pprint(submissions)
# Out:
# [{'claim': '光學顯微鏡是以電磁學原理來將不可見或難見的微小物放大至肉眼可見的儀器。',
#   'id': 5208,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '產絲的蠶或產蜜的蜜蜂爲提供間接經濟利益的昆蟲。',
#   'id': 1019,
#   'predicted_evidence': [('昆蟲', 23), ('昆蟲', 22)],
#   'predicted_label': 'supports'},
#  {'claim': '波蘭西部的綠山城縣平均每平方公里的土地有0人。',
#   'id': 8514,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': 'Vivien Leigh主演魂斷藍橋中的女配角。',
#   'id': 1874,
#   'predicted_evidence': [('魂斷藍橋', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': '侯孝賢改編自唐代文言文學的電影獲得金馬獎最佳劇情片獎。',
#   'id': 8352,
#   'predicted_evidence': [('鼕鼕的假期', 1),
#                          ('李行', 0),
#                          ('侯孝賢', 0),
#                          ('刺客聶隱娘', 0),
#                          ('鄧育昆', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '國務院前副總理的姪子薄熙來在2012年9月被開除黨籍 。',
#   'id': 4603,
#   'predicted_evidence': [('薄熙來', 7), ('薄熙來', 1), ('薄熙來', 2)],
#   'predicted_label': 'refutes'},
#  {'claim': '水星凌日曾發生過。',
#   'id': 3147,
#   'predicted_evidence': [('水星凌日_(金星)', 0),
#                          ('水星凌日', 1),
#                          ('水星凌日', 2),
#                          ('水星凌日', 5)],
#   'predicted_label': 'supports'},
#  {'claim': '馬克思在自己的作品中論述了馬克思主義政治經濟學的基本概念。',
#   'id': 5829,
#   'predicted_evidence': [('社會主義政治經濟學', 11),
#                          ('社會主義政治經濟學', 12),
#                          ('社會主義政治經濟學', 0),
#                          ('馬克思主義政治經濟學', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '一貫道相信最高神祇無生老母派遣轉世成銀公祖師路中一的彌勒佛拯救凡間。',
#   'id': 2656,
#   'predicted_evidence': [('無生老母', 0), ('一貫道', 4), ('一貫道', 7)],
#   'predicted_label': 'supports'},
#  {'claim': '回族世居內蒙古至山西 、 陝西 、 甘肅 ， 以至於新疆和中亞一帶，受中亞與西亞中伊斯蘭教傳播的影響 ， 許多回族成爲穆斯林。',
#   'id': 3887,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '天衛四的表面呈現暗紅色，小行星和彗星相撞後所形成其主要地形，並存在許多撞擊坑。',
#   'id': 2268,
#   'predicted_evidence': [('婉達撞擊坑', 2),
#                          ('莫札特撞擊坑', 1),
#                          ('桑德撞擊坑', 0),
#                          ('天衛四', 8),
#                          ('巴頓撞擊坑', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '玲子·艾爾斯沃斯身上有美洲血統與亞洲血統。',
#   'id': 7468,
#   'predicted_evidence': [('玲子·艾爾斯沃斯', 2), ('威爾斯', 102), ('日本', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': '於西元2000年以前傳入臺灣的法輪功主要以口耳相傳介紹來介紹功法，是由中國傳入。',
#   'id': 9045,
#   'predicted_evidence': [('臺灣漢語音韻學研究', 1),
#                          ('法輪功在臺灣', 4),
#                          ('臺灣漢語音韻學研究', 0),
#                          ('中古漢語', 0),
#                          ('法輪功在臺灣', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '由同名小說改編的Kramer vs. Kramer 拿到了五項奧斯卡獎項。',
#   'id': 3693,
#   'predicted_evidence': [('克藍瑪對克藍瑪', 1), ('克藍瑪對克藍瑪', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '研究地震波時，反射十分重要，通過對海浪形狀的檢測以研究地震與海嘯 。',
#   'id': 4173,
#   'predicted_evidence': [('地震波', 5),
#                          ('地震學', 0),
#                          ('地震儀', 0),
#                          ('地震波', 6),
#                          ('反射_(物理學)', 7)],
#   'predicted_label': 'refutes'},
#  {'claim': '思想與宇宙命運被學者認爲屬於彌涅耳瓦以外的羅馬神祇所化身。',
#   'id': 3289,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '樂山大佛建造於唐朝而且花了90年。',
#   'id': 133,
#   'predicted_evidence': [('樂山大佛', 1),
#                          ('表功牌坊', 0),
#                          ('莫干山92號', 3),
#                          ('樂山大佛', 0),
#                          ('西林寺_(香港)', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '韓劇挖掘人性之真善美、倡導仁、誠、恕，是個適合家庭一起觀看的電視劇。',
#   'id': 2722,
#   'predicted_evidence': [('韓國電視劇', 16), ('韓國電視劇', 17)],
#   'predicted_label': 'refutes'},
#  {'claim': '基於可擴展標記語言的標記語言是XBRL。',
#   'id': 1838,
#   'predicted_evidence': [('XML', 0),
#                          ('XBRL', 0),
#                          ('可擴展樣式語言', 0),
#                          ('XC_(編程語言)', 3),
#                          ('XC_(編程語言)', 2)],
#   'predicted_label': 'supports'},
#  {'claim': '在1980年代初，史蒂夫·喬布斯使蘋果引入全錄帕洛奧圖中心 （ Xerox PARC ） '
#            '的滑鼠驅動圖形用戶介面技術加強了電腦的易用性和普及，離開蘋果公司後也成立了計算機動畫製片廠 。',
#   'id': 3395,
#   'predicted_evidence': [('Apple_II', 1),
#                          ('史蒂夫·喬布斯', 5),
#                          ('Apple_Lisa', 0),
#                          ('麥金塔', 3),
#                          ('皮克斯動畫工作室', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '「211工程」中唯一的政法類高校的中國政法大學沒有隸屬於直屬機關下，而是獨立運作的私人大學。',
#   'id': 5437,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '珠江三角洲範圍包括珠江干流。',
#   'id': 4278,
#   'predicted_evidence': [('河口', 0),
#                          ('珠江三角洲', 2),
#                          ('平川河', 2),
#                          ('豐川', 0),
#                          ('平川河', 1)],
#   'predicted_label': 'supports'},
#  {'claim': '亞伯拉罕諸教爲基督宗教、伊斯蘭教與猶太教的通則。',
#   'id': 663,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '意大利威尼斯影展頒發給最佳影片的首獎從1949年開始稱作金獅獎，是電影界最高榮譽之一。',
#   'id': 5583,
#   'predicted_evidence': [('金獅獎', 4),
#                          ('威尼斯電影節', 26),
#                          ('金獅獎_(消歧義)', 2),
#                          ('金獅獎', 0),
#                          ('金獅獎_(消歧義)', 1)],
#   'predicted_label': 'supports'},
#  {'claim': '對日民間索賠的類型包含二戰後幾十年因遺留的炸彈造成傷害的賠償。',
#   'id': 5237,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '汾河是山西人的母親河，其上游是太原市主要水來源。',
#   'id': 8329,
#   'predicted_evidence': [('康王河', 1),
#                          ('匯河', 0),
#                          ('土庫溪', 0),
#                          ('康王河', 0),
#                          ('汾河', 8)],
#   'predicted_label': 'refutes'},
#  {'claim': '東帝汶在澳洲等地區的支持下通過電影決定獨立後，於2002年真正獨立。',
#   'id': 1766,
#   'predicted_evidence': [('東帝汶', 3), ('東帝汶省', 11)],
#   'predicted_label': 'supports'},
#  {'claim': '普京在1999年的最後一天從總理成爲代理部長。',
#   'id': 3915,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '位於阿拉伯半島東南沿海的阿曼蘇丹國南部和東部臨印度洋。',
#   'id': 3108,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '傳說有一位北歐神明索爾，會在雷雨交加時乘坐交通工具巡視人間。',
#   'id': 3042,
#   'predicted_evidence': [('索爾', 1), ('索爾', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '行政法與政府行政部門的決策活動關係疏遠。',
#   'id': 909,
#   'predicted_evidence': [('行政法', 4), ('行政機關', 7), ('行政法', 5)],
#   'predicted_label': 'refutes'},
#  {'claim': '英國第一個由國家成立的廣播機構是BBC，文化傳媒與體育大臣負責監管。',
#   'id': 3225,
#   'predicted_evidence': [('英國廣播公司', 2), ('英國廣播公司', 3), ('英國廣播公司', 4)],
#   'predicted_label': 'supports'},
#  {'claim': '戰爭與和平是俄國作家列夫 · 托爾斯泰的一條函數。',
#   'id': 1109,
#   'predicted_evidence': [('戰爭與和平_(消歧義)', 0),
#                          ('俄瑞戰爭', 0),
#                          ('史詩', 4),
#                          ('戰爭與和平', 0),
#                          ('戰爭與和平_(電影系列)', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': '燕山大學，簡稱燕大，一隻位在中國河北省秦皇島市的鱷魚。',
#   'id': 659,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '韓國政治家高建的社會評價充斥著負面訊息。',
#   'id': 4735,
#   'predicted_evidence': [('韓粉', 1),
#                          ('反韓', 1),
#                          ('反韓', 2),
#                          ('對朝鮮民主主義人民共和國的媒體偏見', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '懷化市，別稱鶴城、五溪，是中華人民共和國湖北省下轄的地級市。',
#   'id': 641,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '螺旋動物，又稱螺旋卵裂動物，是原口動物的一大分支。',
#   'id': 4750,
#   'predicted_evidence': [('卵囊螺', 0),
#                          ('螺旋動物', 1),
#                          ('動物分類表', 59),
#                          ('紀伊尖卷螺', 0),
#                          ('螺旋動物', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '六和敬指6種需要遵循的生活態度，是佛教術語。',
#   'id': 6073,
#   'predicted_evidence': [('六和敬', 0), ('六和敬', 6)],
#   'predicted_label': 'supports'},
#  {'claim': '卡夫卡的短篇故事合集在他在世時出版。',
#   'id': 6689,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '金朝以 “ 大金 ” 爲口號是因爲皇帝希望國府永遠不變不壞。',
#   'id': 5380,
#   'predicted_evidence': [('王孫卿', 5),
#                          ('金朝', 17),
#                          ('都勃極烈', 0),
#                          ('金朝', 16),
#                          ('金上盛備', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': 'iPod mini的物理量比iPod輕。',
#   'id': 5418,
#   'predicted_evidence': [('重量', 0), ('IPod_mini', 1)],
#   'predicted_label': 'supports'},
#  {'claim': '歐洲民族中各個民族基本是以手指數量劃分，同國家的同一手指數量的人群承認屬於同一族群，也有人更願意強調自己的腳趾。',
#   'id': 1250,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '兒玉利國 ， 日本鹿兒島縣人 ， 爲明治時代官員 ， 日軍海軍的少將，他謝絕參與牡丹社的調查活動 。',
#   'id': 8943,
#   'predicted_evidence': [('張子涇', 0),
#                          ('兒玉利國', 2),
#                          ('島居辰次郎', 0),
#                          ('草鹿任一', 0),
#                          ('兒玉利國', 1)],
#   'predicted_label': 'refutes'},
#  {'claim': '朱棣文曾在斯坦福大學授教。',
#   'id': 4898,
#   'predicted_evidence': [('朱棣文', 9)],
#   'predicted_label': 'supports'},
#  {'claim': '威廉·華茲華斯是生活在蘇格蘭湖區的詩人代表。',
#   'id': 6456,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '身爲晚清進士的沈鈞儒，祖籍在嘉興，是江蘇省蘇州人。',
#   'id': 3877,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '皮特·烏斯蒂諾夫爵士有瑞士、埃塞俄比亞、意大利以及法國的血統，在1990年被法國女王伊麗莎白二世授予爵士稱號，曾兩次榮獲奧斯卡獎。',
#   'id': 4920,
#   'predicted_evidence': [('皮特·烏斯蒂諾夫', 1),
#                          ('皮特·烏斯蒂諾夫', 2),
#                          ('伊莉莎白·馮·奧地利_(1554年－1592年)', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': '最流行的《 毛主席語錄 》 禁止使用波長大約爲630到750nm的可見光色作爲顏色。',
#   'id': 5996,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '普路託是羅馬神話中陰間的主宰。',
#   'id': 1179,
#   'predicted_evidence': [('普路託斯', 2), ('勒穆瑞斯', 0), ('普路託', 0), ('波塔_(征服者)', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '以高性能纖維爲增強材料的複合材料被大量運用到航空航天行業，爲了與第一代玻璃纖維增強樹脂複合材料相區別，稱作先進複合材料。',
#   'id': 3784,
#   'predicted_evidence': [('複合材料', 9),
#                          ('碳纖維', 10),
#                          ('複合材料', 8),
#                          ('樹脂基複合材料', 0),
#                          ('纖維', 2)],
#   'predicted_label': 'supports'},
#  {'claim': '第七號交響曲的標題晨之歌不是由奧地利作曲家馬勒所命名的。',
#   'id': 8921,
#   'predicted_evidence': [('第7號交響曲_(馬勒)', 1)],
#   'predicted_label': 'refutes'},
#  {'claim': '於1982年與山下達郎結婚的竹內瑪莉亞，當初是以偶像歌手身分出道。',
#   'id': 3087,
#   'predicted_evidence': [('竹內瑪莉亞', 0), ('竹內瑪莉亞', 1)],
#   'predicted_label': 'supports'},
#  {'claim': '經濟學家楊小凱提出了新興古典經濟學與超邊際分析方法和理論，曾是哈佛大學客座教授。',
#   'id': 6616,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '1917年俄羅斯人亞歷山大·克倫斯基阻止了民主革命推翻了沙皇的統治，卻在同年又被推翻。',
#   'id': 3828,
#   'predicted_evidence': [('格奧爾基·葉夫根耶維奇·李沃夫', 2),
#                          ('1917年俄國革命', 0),
#                          ('亞歷山大·克倫斯基', 0),
#                          ('俄國二月革命', 0),
#                          ('1917年俄國革命', 2)],
#   'predicted_label': 'refutes'},
#  {'claim': '韓國行政道全羅北道的首府在聯合國教科文組織指定的美食城市之一賓州。',
#   'id': 3058,
#   'predicted_evidence': [('全州市', 9),
#                          ('玉流館', 1),
#                          ('全州市', 8),
#                          ('全羅北道', 14),
#                          ('朝鮮烹飪協會', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': '伍迪·艾倫對於演一些不安的 、 煩躁的以及帶有神經質的角色相當反感且不熟悉。',
#   'id': 493,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '在 2004 年，時代雜誌將伍迪·艾倫評爲百大滑稽演員 （ stand up comics ） 第四位。',
#   'id': 485,
#   'predicted_evidence': [('伍迪·艾倫', 57), ('喜劇中心', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '醋一般按造購買方式可分爲釀造醋等共三種種類，釀造醋是以穀類等天然原料爲主 ， 再加上食鹽 、 穀皮等發酵而成的食醋 。',
#   'id': 4025,
#   'predicted_evidence': [('釀造醋', 3), ('釀造醋', 0), ('釀造醋', 1), ('獨流老醋', 4)],
#   'predicted_label': 'refutes'},
#  {'claim': '食鹽、芒硝、石油和天然氣豐富的卡拉卡爾帕克斯坦共和國，屬於突厥語族，居民是卡拉卡爾帕克族人。',
#   'id': 5568,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '鎖麟囊頒獎在上海黃金戲院。',
#   'id': 950,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '臺北市士林區華岡藝校的創始人爲前教育部部長張其昀。',
#   'id': 6126,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '俗稱電石氣的炔烴化合物乙炔，聚合生成乙烯基乙炔和苯需要遠高於攝氏400度以上。',
#   'id': 5458,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '康托爾死後數十年，大多數數學家已經接受他的理論。',
#   'id': 5692,
#   'predicted_evidence': [('格奧爾格·康托爾', 14),
#                          ('里斯表示定理', 0),
#                          ('納森·雅各布森', 0),
#                          ('哈斯勒·惠特尼', 0),
#                          ('讓路易·韋迪耶', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '印度佛教史中的根本分裂是指上座部與大衆部的教派分裂，其原因是喫素議題紛爭。',
#   'id': 4245,
#   'predicted_evidence': [('部派佛教', 0),
#                          ('部派佛教', 3),
#                          ('上座部佛教', 9),
#                          ('部派佛教', 2),
#                          ('上座部佛教', 8)],
#   'predicted_label': 'refutes'},
#  {'claim': '受章回小說《 三國演義 》的影響普遍認爲關羽與劉備 、 趙子龍義結金蘭，因此排行第二的關羽又稱關二爺。',
#   'id': 4852,
#   'predicted_evidence': [('張尚', 1),
#                          ('關羽', 15),
#                          ('三國演義', 0),
#                          ('戰國無雙3', 0),
#                          ('張尚', 2)],
#   'predicted_label': 'supports'},
#  {'claim': '一般線性群中典型符號是 GLn(F)或GL ( n, F ) ，而群 GL ( n, F ) '
#            '和它的子群經常叫做線性群或矩陣群，在群表示理論中引發對空間對稱和一般向量空間對稱的研究，有很重要的地位。',
#   'id': 4539,
#   'predicted_evidence': [('可均群', 0),
#                          ('一般線性群', 6),
#                          ('一般線性群', 19),
#                          ('全形_(數學)', 0),
#                          ('凱萊定理', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '土衛十一是木星的一顆內側衛星。',
#   'id': 2045,
#   'predicted_evidence': [('木衛六十一', 0),
#                          ('土衛十一', 0),
#                          ('木衛十一', 0),
#                          ('木衛十三', 0),
#                          ('木衛八', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '墨家邏輯是一個邏輯學體系，主要以三物論爲代表。',
#   'id': 3837,
#   'predicted_evidence': [('邏輯', 7),
#                          ('墨家', 8),
#                          ('邏輯', 6),
#                          ('邏輯', 9),
#                          ('數理邏輯', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '高安公寓在上海康平路1號公寓對面3公尺。',
#   'id': 8153,
#   'predicted_evidence': [('高安公寓', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': '流產是指胚胎或胎兒發育到之前發生基因突變 。',
#   'id': 3556,
#   'predicted_evidence': [('流產', 1)],
#   'predicted_label': 'refutes'},
#  {'claim': '氫氣雙原子分子鍵長約74皮米。',
#   'id': 8717,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '弗拉基米爾·普京於2008年卸任總統後退休。',
#   'id': 819,
#   'predicted_evidence': [('弗拉基米爾·普京', 175)],
#   'predicted_label': 'refutes'},
#  {'claim': '中國南北朝時舉行的崇義郡位於現今的湖北省。',
#   'id': 9036,
#   'predicted_evidence': [('順義郡', 0),
#                          ('崇義郡', 4),
#                          ('百梁郡', 0),
#                          ('安昌郡_(劉宋)', 0),
#                          ('崇義郡', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '愛爾蘭的體積約爲七萬平方公里。',
#   'id': 831,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '臺北市萬華區老松安養院是臺北市的指定古蹟建築。',
#   'id': 5121,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '世界上第四大耕作水源的大麥是一種禾本科植物，起源於可在中東發現的野生大麥，有別稱三月黃。',
#   'id': 5592,
#   'predicted_evidence': [('大麥', 2), ('大麥', 0), ('大麥', 1)],
#   'predicted_label': 'supports'},
#  {'claim': '屬是生物學分類學中的一個形容詞，用於生物學中的生物和化石生物以及病毒的生物分類。',
#   'id': 1617,
#   'predicted_evidence': [('名詞', 0),
#                          ('生物分類法', 11),
#                          ('屬', 1),
#                          ('生物分類法', 10),
#                          ('生物分類法', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '荷馬史詩確定是由來自美洲詩人所創作的。',
#   'id': 5283,
#   'predicted_evidence': [('草葉集', 0),
#                          ('理查·布羅提根', 0),
#                          ('韋切爾·林賽', 0),
#                          ('弗蘭克·奧哈拉', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '南京大學附屬中學，位於中國江蘇省 。',
#   'id': 2172,
#   'predicted_evidence': [('浙江省永康中學', 0),
#                          ('江蘇省', 0),
#                          ('南大附中', 2),
#                          ('南京市孫家初級中學', 0),
#                          ('江蘇省江浦高級中學', 0)],
#   'predicted_label': 'refutes'},
#  {'claim': '科隆在二十世紀後期農業佔大宗。',
#   'id': 4333,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '勇度是漫威多格漫畫中藍色皮膚的虛構人物。',
#   'id': 7737,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '臺南市美術館僅有一棟場館建築位於臺南市中西區。',
#   'id': 7793,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '朱棣文曾在泰國大學當老師。',
#   'id': 4902,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '利用澱粉水解、發酵產生糖分後製成的酒精飲料稱爲啤酒，啤酒釀造工業已具有全球性。',
#   'id': 8431,
#   'predicted_evidence': [('啤酒廠', 1),
#                          ('啤酒', 15),
#                          ('啤酒', 14),
#                          ('啤酒廠', 2),
#                          ('啤酒', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '不可否認的是 ， 該工程對人們瞭解與研究中國上古歷史有極其重要的參考價值 。',
#   'id': 539,
#   'predicted_evidence': [('中國大歷史', 0), ('系年', 0), ('孟森', 1), ('國史大綱', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '良好的代碼風格可以幫助程序員早睡早起。',
#   'id': 422,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '華南理工大學曾名華南工學院，是中華人民共和國頂尖高校之一。',
#   'id': 2375,
#   'predicted_evidence': [('華南理工大學', 58),
#                          ('山東輕工職業學院', 0),
#                          ('柳州工學院', 0),
#                          ('華南理工大學', 57),
#                          ('中國勞動關係學院', 0)],
#   'predicted_label': 'supports'},
#  {'claim': '由於日本的教育裝備與物資皆遜於盟軍，因此發展出特別攻擊隊以最少資源獲取最大破壞力。',
#   'id': 5869,
#   'predicted_evidence': None,
#   'predicted_label': 'NOT ENOUGH INFO'},
#  {'claim': '尼克·貝爾格自2004年失蹤',
#   'id': 187,
#   'predicted_evidence': [('尼克·貝爾格', 1)],
#   'predicted_label': 'supports'},
#  {'claim': '臺灣最高峯所在的南投縣，擁有水果、酒、茶等特產。',
#   'id': 7314,
#   'predicted_evidence': [('南投縣', 4),
#                          ('南投縣', 0),
#                          ('南投縣', 3),
#                          ('陽明山國家公園', 1),
#                          ('陽明山國家公園', 0)],
#   'predicted_label': 'refutes'}]

# %%
# 4. Respond [R]

for form in submissions:
  form.pop('claim', None)

submissions.extend([
  {
    'id': query_id,
    'predicted_label': 'NOT ENOUGH INFO',
    'predicted_evidence': None,
  }
  for query_id in list(queries.keys())[90:] # [DEV]
])
submissions.sort(key=lambda s: s['id'])

open('submission.jsonl', 'w').close()
with open('submission.jsonl', 'ab') as submission_file:
  for form in submissions:
    submission_file.write(encode(form))
    submission_file.write(b'\n')

# %%
score = 0.0384
public_test_count = 989
submitted_count = 90
model_accuracy = score * public_test_count / submitted_count
print(f'Accuracy: {model_accuracy:.3f}')
# Out:
# Accuracy: 0.422
